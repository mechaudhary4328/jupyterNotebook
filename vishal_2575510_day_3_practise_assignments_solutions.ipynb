# %% [markdown]
# # 1. Write a python function that copies a file reading and writing up to 50 characters at a time.

# %%
def copy_file_in_chunks(source_file_path, destination_file_path):
    chunk_size = 50
    try:
        with open(source_file_path, 'r') as source_file, open(destination_file_path, 'w') as destination_file:
            while True:
                chunk = source_file.read(chunk_size)
                if not chunk:
                    break
                destination_file.write(chunk)
    except FileNotFoundError:
        print(f"File not found: {source_file_path}")
    except Exception as e:
        print(f"An error occurred: {str(e)}")






source_file_path = 'D:\practise\File1.txt'
destination_file_path = 'D:\practise\File2.txt'
copy_file_in_chunks(source_file_path, destination_file_path)

# %% [markdown]
# # 2. Print all numbers present in the text file and print the number of blank spaces in that file.

# %%
with open('test.txt', 'w') as file:
    file.write("GOOD AFTERNOON EVERYONE\n")
    file.write("This is a test file.")

with open('test.txt', 'r') as file:
    file_contents = file.read()

print(file_contents)

file = open("test.txt", "r")

count = 0

while True:
    char = file.read(1)
    if char.isspace():
        count += 1
    if not char:
        break

print("The number blank spaces in the test file are : ",count)
# Out:
# GOOD AFTERNOON EVERYONE
# This is a test file.
# The number blank spaces in the test file are :  7

# %% [markdown]
# # 3. Write a function called sed that takes as arguments a pattern string, a replacement string. and two filenames; it should read the first file and write the contents into the second file (creating it if necessary). If the pattern string appears anywhere in the file, it should be replaced with the replacement string. If an error occurs while opening, reading, writing, or closing files, your program should catch the exception, print an error message, and exit.

# %%
def sed(pattern, replacement, input_filename, output_filename):
    try:
        with open(input_filename, 'r') as input_file:
            file_content = input_file.read()
        modified_content = file_content.replace(pattern, replacement)
        with open(output_filename, 'w') as output_file:
            output_file.write(modified_content)
        print(f"Pattern '{pattern}' replaced with '{replacement}' successfully.")
    except FileNotFoundError:
        print(f"Error: The file '{input_filename}' was not found.")
    except Exception as e:
        print(f"An error occurred: {e}")
pattern = " vishal chaudhary"
replacement = "VISHAL CHAUDHARY"
input_filename = "input.txt"
output_filename = "output.txt"

sed(pattern, replacement, input_filename, output_filename)
# Out:
# Pattern ' vishal chaudhary' replaced with 'VISHAL CHAUDHARY' successfully.

# %% [markdown]
# # 4. Log File Analysis: You have a log file containing records of user activities on a website. Each line in the file represents a log entry with details like timestamp, user ID, and action performed. Your task is to analyze this log file.
#
# a. Write Python code to read the log file and extract specific information, such as thenumber of unique users or the most
# common action.
# b. How would you handle large log files efficiently without loading the entire file into memory?

# %%
# a. Write Python code to read the log file and extract specific information, such as thenumber of unique users or the mostcommon action.
import collections
log_file_path = 'D:\practise\logfile.txt'
unique_users = set()
action_count = collections.Counter()
with open(log_file_path, 'r') as log_file:
    for line in log_file:
                timestamp, user_id, action = line.strip().split(',')
        unique_users.add(user_id)
        action_count[action] += 1
num_unique_users = len(unique_users)
most_common_action, most_common_count = action_count.most_common(1)[0]
print(f"Number of unique users: {num_unique_users}")
print(f"Most common action: {most_common_action} (Count: {most_common_count})")
# Out:
#   File <tokenize>:9
#     unique_users.add(user_id)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# b. How would you handle large log files efficiently without loading the entire file into memory?

# %% [markdown]
# # 5. Text File Search and Replace: You have a text file with a large amount of text, and you want to search for specific words or phrases and replace them with new content.

# %%
# a. Write Python code to search for and replace text within a text file
def search_and_replace(file_path, search_str, replace_str):
    with open(file_path, 'r') as file:
        file_content = file.read()

    modified_content = file_content.replace(search_str, replace_str)

    with open(file_path, 'w') as file:
        file.write(modified_content)

file_path = 'D:\practise\File3.txt'
search_str = 'Python'
replace_str = 'Java'
search_and_replace(file_path, search_str, replace_str)

# %%
#b. How would you handle cases where you need to perform multiple replacements in a single pass?
def multiple_search_and_replace(file_path, replace_dict):
    with open(file_path, 'r') as file:
        file_content = file.read()

    for search_str, replace_str in replace_dict.items():
        file_content = file_content.replace(search_str, replace_str)

    with open(file_path, 'w') as file:
        file.write(file_content)

file_path = 'D:\practise\File3.txt'
replace_dict = {
    'dynamically': 'statically',
    'is': 'IS',
    'a': 'A',
}

multiple_search_and_replace(file_path, replace_dict)

# %% [markdown]
# # 6. Write a Python script that concatenates the contents of multiple text files into a single output file. Allow the user to specify the input files and the output file.

# %%
file1 = open('text1.txt', 'r')
file2 = open('text2.txt', 'r')
content1 = file1.read()
content2 = file2.read()
file1.close()
file2.close()
destination_file = open('concatenated.txt', 'w')
destination_file.write(content1 + content2)
destination_file.close()
print(destination_file)
destination_file = open('concatenated.txt', 'r')
destination_file.read()
# Out:
# <_io.TextIOWrapper name='concatenated.txt' mode='w' encoding='cp1252'>
# "Python is a computer programming language often used to build websites and software, automate tasks, and conduct data analysis. Python is a general-purpose language, meaning it can be used to create a variety of different programs and isn't specialized for any specific problems.Life can be filled with its ups and downs, but remember that you have the strength and resilience to overcome any challenges that come your way. Take a deep breath, embrace the opportunities that each day brings, and keep moving forward towards your goals and dreams."

# %% [markdown]
# # 7. You are given a text file named input.txt containing a list of words, one word per line. Your task is to create a Python program that reads the contents of input.txt, processes the words, and writes the result to an output file named output.txt.
#
# a. The program should perform the following operations:
#
# i. Read the words from input.txt.
#
# ii. For each word in the input file, calculate the length of the word and store it
#
# in a dictionary where the word is the key, and the length is the value.
#
# iii. Write the word-length dictionary to output.txt in the following format:
#
# iv.Close both input and comput files property
#
# v.Write Python code is accomplish this task. Ensure proper error handling for file operations

# %%
#a. The program should perform the following operations:
#i. Read the words from input.txt.
log_file_path = "D:\practise\logfile.txt"  
try:
    with open('D:\practise\logfile.txt', 'r') as log_file:
        log_content = log_file.read()
        words = log_content.split()
        for word in words:
            print(word)
except FileNotFoundError:
    print(f"The file '{D:\practise\logfile.txt}' was not found.")
except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# [2023-09-09
# 21:51:29]
# Executing
# bootstrap
# tasks
# [2023-09-09
# 21:51:29]
# OpenJDK
# Runtime
# Environment
# 17.0.7+7
# [2023-09-09
# 21:51:29]
# Product
# org.eclipse.products.epp.package.java.2023-06
# [2023-09-09
# 21:51:29]
# Bundle
# org.eclipse.oomph.setup
# 1.26.0.v20230416-0656,
# build=5945,
# branch=c5558820f367665758d4d719b7553a02ff4954e0
# [2023-09-09
# 21:51:29]
# Bundle
# org.eclipse.oomph.setup.core
# 1.27.0.v20230402-0730,
# build=5945,
# branch=c5558820f367665758d4d719b7553a02ff4954e0
# [2023-09-09
# 21:51:29]
# Bundle
# org.eclipse.oomph.setup.p2
# 1.19.0.v20230416-1150,
# build=5945,
# branch=c5558820f367665758d4d719b7553a02ff4954e0
# [2023-09-09
# 21:51:29]
# Performing
# P2
# Director
# (Eclipse
# IDE
# for
# Java
# Developers
# (2023-06))
# [2023-09-09
# 21:51:29]
# Offline
# =
# false
# [2023-09-09
# 21:51:29]
# Mirrors
# =
# true
# [2023-09-09
# 21:51:29]
# Resolving
# 26
# requirements
# from
# 3
# repositories
# to
# C:\Users\eluri\eclipse\java-2023-06\eclipse
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:epp.package.java
# [4.28.0,5.0.0)
# (filter=(|(&(osgi.arch=aarch64)(osgi.os=linux)(osgi.ws=gtk))(&(osgi.arch=aarch64)(osgi.os=macosx)(osgi.ws=cocoa))(&(osgi.arch=x86_64)(osgi.os=linux)(osgi.ws=gtk))(&(osgi.arch=x86_64)(osgi.os=macosx)(osgi.ws=cocoa))(&(osgi.arch=x86_64)(osgi.os=win32)(osgi.ws=win32))))
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.platform.feature.group
# [4.28.0,5.0.0)
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.rcp.feature.group
# [4.28.0,5.0.0)
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.buildship.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.eclemma.feature.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.egit.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.epp.mpc.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.jdt.bcoview.feature.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.jdt.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.jgit.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.m2e.feature.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.m2e.lemminx.feature.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.m2e.logback.feature.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.mylyn.commons.activity.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.mylyn.egit.feature.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.mylyn.git.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.mylyn.github.feature.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.mylyn.hudson.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.mylyn.ide_feature.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.mylyn.java_feature.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.mylyn.reviews.feature.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.mylyn.wikitext_feature.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.tips.feature.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.tm.terminal.feature.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.wildwebdeveloper.xml.feature.feature.group
# [2023-09-09
# 21:51:29]
# Requirement
# org.eclipse.equinox.p2.iu:org.eclipse.oomph.setup.feature.group
# [2023-09-09
# 21:51:29]
# Repository
# https://download.eclipse.org/technology/epp/packages/2023-06/202306081200
# [2023-09-09
# 21:51:29]
# Repository
# https://download.eclipse.org/releases/2023-06/202306141000
# [2023-09-09
# 21:51:29]
# Repository
# https://download.eclipse.org/oomph/updates/milestone/latest
# [2023-09-09
# 21:51:36]
# Calculating
# requirements
# and
# dependencies.
# [2023-09-09
# 21:51:36]
# Computing
# prerequisite
# plan
# [2023-09-09
# 21:51:39]
# Collecting
# 351
# artifacts
# from
# https://download.eclipse.org/releases/2023-06/202306141000
# [2023-09-09
# 21:51:41]
# Downloading
# org.eclipse.platform_root
# [2023-09-09
# 21:51:41]
# Downloading
# org.eclipse.jdt.core.formatterapp
# [2023-09-09
# 21:51:41]
# Downloading
# org.eclipse.e4.core.di.extensions
# [2023-09-09
# 21:51:41]
# Downloading
# org.eclipse.egit
# [2023-09-09
# 21:51:41]
# Downloading
# org.eclipse.rcp
# [2023-09-09
# 21:51:41]
# Downloading
# org.eclipse.core.net.win32.x86_64
# [2023-09-09
# 21:51:41]
# Downloading
# org.eclipse.ecf.provider.filetransfer.ssl
# [2023-09-09
# 21:51:41]
# Downloading
# org.eclipse.e4.ui.swt.win32
# [2023-09-09
# 21:51:41]
# Downloading
# org.eclipse.e4.ui.ide
# [2023-09-09
# 21:51:41]
# Downloading
# org.eclipse.e4.core.di.annotations
# [2023-09-09
# 21:51:42]
# Fetching
# org.eclipse.ecf.provider.filetransfer.ssl_1.1.0.v20230422-0242.jar
# from
# https://mirrors.jevincanders.net/eclipse/releases/2023-06/202306141000/plugins/
# (11.58kB)
# [2023-09-09
# 21:51:42]
# Fetching
# org.eclipse.platform_root_4.28.0.v20230605-0440
# from
# https://mirror.umd.edu/eclipse/releases/2023-06/202306141000/binary/
# (196B)
# [2023-09-09
# 21:51:42]
# Downloading
# junit-platform-suite-commons
# [2023-09-09
# 21:51:42]
# Fetching
# org.eclipse.jdt.core.formatterapp_1.2.0.v20230323-1537.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (14.43kB)
# [2023-09-09
# 21:51:42]
# Fetching
# org.eclipse.e4.ui.swt.win32_1.2.0.v20230501-1823.jar
# from
# https://mirrors.xmission.com/eclipse/releases/2023-06/202306141000/plugins/
# (12.12kB)
# [2023-09-09
# 21:51:43]
# Fetching
# org.eclipse.e4.core.di.extensions_0.18.0.v20230429-1914.jar
# from
# https://ftp.fau.de/eclipse/releases/2023-06/202306141000/plugins/
# (12.92kB)
# [2023-09-09
# 21:51:43]
# Downloading
# org.eclipse.e4.ui.widgets
# [2023-09-09
# 21:51:43]
# Fetching
# org.eclipse.egit_6.6.0.202305301015-r.jar
# from
# https://mirror.csclub.uwaterloo.ca/eclipse/releases/2023-06/202306141000/plugins/
# (13.13kB)
# [2023-09-09
# 21:51:43]
# Downloading
# org.eclipse.m2e.sourcelookup
# [2023-09-09
# 21:51:43]
# Fetching
# org.eclipse.e4.ui.ide_3.17.0.v20230317-0802.jar
# from
# https://mirror.clarkson.edu/eclipse/releases/2023-06/202306141000/plugins/
# (13.31kB)
# [2023-09-09
# 21:51:43]
# Fetching
# org.eclipse.rcp_4.28.0.v20230605-0440.jar
# from
# https://ftp2.osuosl.org/pub/eclipse/releases/2023-06/202306141000/plugins/
# (12.91kB)
# [2023-09-09
# 21:51:43]
# Fetching
# org.eclipse.e4.core.di.annotations_1.8.0.v20230429-1914.jar
# from
# https://eclipse.mirror.rafal.ca/releases/2023-06/202306141000/plugins/
# (13.81kB)
# [2023-09-09
# 21:51:43]
# Fetching
# junit-platform-suite-commons_1.9.3.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (14.94kB)
# [2023-09-09
# 21:51:43]
# Downloading
# org.eclipse.mylyn.versions.ui
# [2023-09-09
# 21:51:43]
# Fetching
# org.eclipse.core.net.win32.x86_64_1.2.0.v20230317-0901.jar
# from
# https://mirror.ibcp.fr/pub/eclipse/releases/2023-06/202306141000/plugins/
# (9.59kB)
# [2023-09-09
# 21:51:43]
# Fetching
# org.eclipse.m2e.sourcelookup_2.0.300.20230520-0934.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (15.21kB)
# [2023-09-09
# 21:51:43]
# Fetching
# org.eclipse.mylyn.versions.ui_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (15.37kB)
# [2023-09-09
# 21:51:44]
# Downloading
# org.eclipse.mylyn.commons.notifications.core
# [2023-09-09
# 21:51:44]
# Downloading
# org.eclipse.jgit
# [2023-09-09
# 21:51:44]
# Downloading
# junit-platform-runner
# [2023-09-09
# 21:51:44]
# Downloading
# org.eclipse.jgit.gpg.bc
# [2023-09-09
# 21:51:44]
# Downloading
# org.eclipse.jgit.http.apache
# [2023-09-09
# 21:51:44]
# Downloading
# org.eclipse.jgit.ssh.apache
# [2023-09-09
# 21:51:44]
# Downloading
# org.eclipse.buildship.compat
# [2023-09-09
# 21:51:44]
# Fetching
# org.eclipse.e4.ui.widgets_1.4.0.v20230317-0802.jar
# from
# https://download.eclipse.org/releases/2023-06/202306141000/plugins/
# (15.11kB)
# [2023-09-09
# 21:51:44]
# Fetching
# org.eclipse.jgit_6.6.0.202305301015-r.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (16.17kB)
# [2023-09-09
# 21:51:44]
# Fetching
# junit-platform-runner_1.9.3.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (16.19kB)
# [2023-09-09
# 21:51:44]
# Fetching
# org.eclipse.mylyn.commons.notifications.core_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (16.02kB)
# [2023-09-09
# 21:51:44]
# Fetching
# org.eclipse.jgit.gpg.bc_6.6.0.202305301015-r.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (16.2kB)
# [2023-09-09
# 21:51:44]
# Downloading
# org.eclipse.buildship.branding
# [2023-09-09
# 21:51:44]
# Downloading
# org.eclipse.team.genericeditor.diff.extension
# [2023-09-09
# 21:51:44]
# Downloading
# org.eclipse.e4.ui.di
# [2023-09-09
# 21:51:44]
# Downloading
# org.eclipse.m2e.binaryproject.ui
# [2023-09-09
# 21:51:44]
# Downloading
# org.eclipse.swt
# [2023-09-09
# 21:51:44]
# Fetching
# org.eclipse.team.genericeditor.diff.extension_1.2.0.v20230317-0901.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (18.13kB)
# [2023-09-09
# 21:51:44]
# Fetching
# org.eclipse.buildship.branding_3.1.7.v20230428-1350.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (17.43kB)
# [2023-09-09
# 21:51:45]
# Downloading
# org.eclipse.ecf.ssl
# [2023-09-09
# 21:51:45]
# Downloading
# org.eclipse.equinox.p2.updatechecker
# [2023-09-09
# 21:51:45]
# Fetching
# org.eclipse.e4.ui.di_1.5.0.v20230501-1823.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (18.17kB)
# [2023-09-09
# 21:51:45]
# Fetching
# org.eclipse.jgit.http.apache_6.6.0.202305301015-r.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/features/
# (16.21kB)
# [2023-09-09
# 21:51:45]
# Fetching
# org.eclipse.m2e.binaryproject.ui_2.0.100.20230520-0934.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (18.78kB)
# [2023-09-09
# 21:51:45]
# Downloading
# org.eclipse.rcp_root
# [2023-09-09
# 21:51:45]
# Fetching
# org.eclipse.jgit.ssh.apache_6.6.0.202305301015-r.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/features/
# (16.21kB)
# [2023-09-09
# 21:51:45]
# Fetching
# org.eclipse.ecf.ssl_1.3.0.v20230507-1921.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (19.13kB)
# [2023-09-09
# 21:51:45]
# Fetching
# org.eclipse.equinox.p2.updatechecker_1.4.0.v20230330-0930.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (20.11kB)
# [2023-09-09
# 21:51:45]
# Fetching
# org.eclipse.buildship.compat_3.1.7.v20230428-1350.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (16.94kB)
# [2023-09-09
# 21:51:45]
# Downloading
# org.eclipse.buildship
# [2023-09-09
# 21:51:45]
# Downloading
# org.eclipse.wildwebdeveloper.xml.feature
# [2023-09-09
# 21:51:45]
# Downloading
# org.eclipse.jdt.bcoview.feature
# [2023-09-09
# 21:51:45]
# Downloading
# junit-platform-suite-api
# [2023-09-09
# 21:51:45]
# Downloading
# org.eclipse.equinox.p2.user.ui
# [2023-09-09
# 21:51:45]
# Fetching
# org.eclipse.rcp_root_4.28.0.v20230605-0440
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/binary/
# (20.24kB)
# [2023-09-09
# 21:51:45]
# Fetching
# org.eclipse.swt_3.124.0.v20230523-1044.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (18.78kB)
# [2023-09-09
# 21:51:45]
# Fetching
# org.eclipse.buildship_3.1.7.v20230428-1350.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.47kB)
# [2023-09-09
# 21:51:45]
# Fetching
# org.eclipse.wildwebdeveloper.xml.feature_1.1.0.202304242122.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.5kB)
# [2023-09-09
# 21:51:45]
# Downloading
# org.eclipse.mylyn.github.feature
# [2023-09-09
# 21:51:45]
# Fetching
# org.eclipse.jdt.bcoview.feature_1.2.0.v20230323-1830.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.63kB)
# [2023-09-09
# 21:51:45]
# Fetching
# org.eclipse.mylyn.github.feature_6.2.1.v20230531-0547.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.78kB)
# [2023-09-09
# 21:51:46]
# Downloading
# org.eclipse.mylyn.monitor
# [2023-09-09
# 21:51:46]
# Downloading
# org.eclipse.mylyn.discovery
# [2023-09-09
# 21:51:46]
# Downloading
# org.eclipse.mylyn.commons.identity
# [2023-09-09
# 21:51:46]
# Fetching
# org.eclipse.mylyn.monitor_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.79kB)
# [2023-09-09
# 21:51:46]
# Fetching
# org.eclipse.mylyn.discovery_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.79kB)
# [2023-09-09
# 21:51:46]
# Downloading
# org.eclipse.m2e.lemminx.feature
# [2023-09-09
# 21:51:46]
# Fetching
# junit-platform-suite-api_1.9.3.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (20.73kB)
# [2023-09-09
# 21:51:46]
# Downloading
# org.eclipse.mylyn.commons
# [2023-09-09
# 21:51:46]
# Downloading
# org.eclipse.mylyn.tasks.ide
# [2023-09-09
# 21:51:46]
# Fetching
# org.eclipse.mylyn.commons.identity_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.79kB)
# [2023-09-09
# 21:51:46]
# Fetching
# org.eclipse.equinox.p2.user.ui_2.4.2000.v20230510-1208.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/features/
# (20.75kB)
# [2023-09-09
# 21:51:46]
# Downloading
# org.eclipse.mylyn.team_feature
# [2023-09-09
# 21:51:46]
# Downloading
# org.eclipse.m2e.logback.feature
# [2023-09-09
# 21:51:46]
# Fetching
# org.eclipse.m2e.lemminx.feature_2.0.4.20230520-0934.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.82kB)
# [2023-09-09
# 21:51:46]
# Fetching
# org.eclipse.mylyn.commons_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.82kB)
# [2023-09-09
# 21:51:46]
# Fetching
# org.eclipse.mylyn.tasks.ide_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.83kB)
# [2023-09-09
# 21:51:46]
# Fetching
# org.eclipse.mylyn.team_feature_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.83kB)
# [2023-09-09
# 21:51:46]
# Downloading
# org.eclipse.mylyn.commons.activity
# [2023-09-09
# 21:51:47]
# Downloading
# org.eclipse.equinox.p2.discovery.feature
# [2023-09-09
# 21:51:47]
# Downloading
# org.eclipse.mylyn.versions
# [2023-09-09
# 21:51:47]
# Downloading
# org.eclipse.mylyn.commons.repositories.http
# [2023-09-09
# 21:51:47]
# Downloading
# org.eclipse.mylyn.reviews.feature
# [2023-09-09
# 21:51:47]
# Downloading
# org.eclipse.mylyn.builds
# [2023-09-09
# 21:51:47]
# Downloading
# org.eclipse.mylyn.git
# [2023-09-09
# 21:51:47]
# Downloading
# org.eclipse.mylyn.context_feature
# [2023-09-09
# 21:51:47]
# Fetching
# org.eclipse.mylyn.commons.activity_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.84kB)
# [2023-09-09
# 21:51:47]
# Downloading
# org.eclipse.mylyn.ide_feature
# [2023-09-09
# 21:51:47]
# Fetching
# org.eclipse.mylyn.commons.repositories.http_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.85kB)
# [2023-09-09
# 21:51:47]
# Fetching
# org.eclipse.mylyn.reviews.feature_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.85kB)
# [2023-09-09
# 21:51:47]
# Fetching
# org.eclipse.mylyn.context_feature_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.86kB)
# [2023-09-09
# 21:51:47]
# Downloading
# org.eclipse.mylyn.commons.repositories
# [2023-09-09
# 21:51:47]
# Downloading
# org.eclipse.equinox.p2.rcp.feature
# [2023-09-09
# 21:51:47]
# Downloading
# org.eclipse.mylyn.commons.notifications
# [2023-09-09
# 21:51:47]
# Fetching
# org.eclipse.mylyn.ide_feature_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.86kB)
# [2023-09-09
# 21:51:47]
# Downloading
# org.eclipse.mylyn.hudson
# [2023-09-09
# 21:51:47]
# Fetching
# org.eclipse.m2e.logback.feature_2.1.2.20230523-2106.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/features/
# (20.83kB)
# [2023-09-09
# 21:51:47]
# Fetching
# org.eclipse.mylyn.commons.notifications_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.87kB)
# [2023-09-09
# 21:51:47]
# Downloading
# org.eclipse.egit
# [2023-09-09
# 21:51:47]
# Downloading
# org.eclipse.equinox.p2.extras.feature
# [2023-09-09
# 21:51:47]
# Fetching
# org.eclipse.mylyn.commons.repositories_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.86kB)
# [2023-09-09
# 21:51:47]
# Downloading
# org.eclipse.rcp
# [2023-09-09
# 21:51:47]
# Fetching
# org.eclipse.equinox.p2.rcp.feature_1.4.2000.v20230510-1208.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.87kB)
# [2023-09-09
# 21:51:47]
# Fetching
# org.eclipse.mylyn.versions_3.26.1.v20230604-1755.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/features/
# (20.84kB)
# [2023-09-09
# 21:51:47]
# Fetching
# org.eclipse.mylyn.hudson_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.9kB)
# [2023-09-09
# 21:51:48]
# Fetching
# org.eclipse.equinox.p2.discovery.feature_1.3.0.v20230322-1009.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/features/
# (20.84kB)
# [2023-09-09
# 21:51:48]
# Downloading
# org.eclipse.mylyn.java_feature
# [2023-09-09
# 21:51:48]
# Fetching
# org.eclipse.mylyn.builds_3.26.1.v20230604-1755.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/features/
# (20.86kB)
# [2023-09-09
# 21:51:48]
# Fetching
# org.eclipse.egit_6.6.0.202305301015-r.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.92kB)
# [2023-09-09
# 21:51:48]
# Downloading
# org.eclipse.mylyn.egit.feature
# [2023-09-09
# 21:51:48]
# Downloading
# org.eclipse.tm.terminal.control.feature
# [2023-09-09
# 21:51:48]
# Fetching
# org.eclipse.mylyn.java_feature_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (20.96kB)
# [2023-09-09
# 21:51:48]
# Downloading
# org.eclipse.tm.terminal.view.feature
# [2023-09-09
# 21:51:48]
# Downloading
# org.eclipse.tm.terminal.connector.ssh.feature
# [2023-09-09
# 21:51:48]
# Fetching
# org.eclipse.mylyn.egit.feature_3.26.1.v20230531-0547.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (21.13kB)
# [2023-09-09
# 21:51:48]
# Downloading
# org.eclipse.m2e.feature
# [2023-09-09
# 21:51:48]
# Downloading
# org.eclipse.help
# [2023-09-09
# 21:51:48]
# Fetching
# org.eclipse.mylyn.git_3.26.1.v20230604-1755.jar
# from
# https://download.eclipse.org/releases/2023-06/202306141000/features/
# (20.86kB)
# [2023-09-09
# 21:51:48]
# Downloading
# org.eclipse.tm.terminal.feature
# [2023-09-09
# 21:51:48]
# Fetching
# org.eclipse.tm.terminal.connector.ssh.feature_11.2.0.202303140100.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (21.24kB)
# [2023-09-09
# 21:51:48]
# Fetching
# org.eclipse.tm.terminal.view.feature_11.2.0.202304132101.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (21.22kB)
# [2023-09-09
# 21:51:48]
# Downloading
# org.eclipse.mylyn_feature
# [2023-09-09
# 21:51:48]
# Downloading
# org.eclipse.equinox.p2.core.feature
# [2023-09-09
# 21:51:48]
# Fetching
# org.eclipse.rcp_4.28.0.v20230605-0440.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/features/
# (20.95kB)
# [2023-09-09
# 21:51:48]
# Fetching
# org.eclipse.mylyn_feature_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (21.42kB)
# [2023-09-09
# 21:51:48]
# Fetching
# org.eclipse.m2e.feature_2.3.0.20230523-2033.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (21.26kB)
# [2023-09-09
# 21:51:48]
# Downloading
# org.eclipse.jdt
# [2023-09-09
# 21:51:49]
# Downloading
# org.eclipse.ecf.core.ssl.feature
# [2023-09-09
# 21:51:49]
# Fetching
# org.eclipse.equinox.p2.core.feature_1.6.1800.v20230509-1332.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (21.47kB)
# [2023-09-09
# 21:51:49]
# Fetching
# org.eclipse.tm.terminal.control.feature_11.2.0.202303140100.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/features/
# (21.19kB)
# [2023-09-09
# 21:51:49]
# Fetching
# org.eclipse.equinox.p2.extras.feature_1.4.2000.v20230509-1332.jar
# from
# https://download.eclipse.org/releases/2023-06/202306141000/features/
# (20.92kB)
# [2023-09-09
# 21:51:49]
# Downloading
# org.eclipse.ecf.core.feature
# [2023-09-09
# 21:51:49]
# Fetching
# org.eclipse.jdt_3.19.100.v20230605-0440.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (21.51kB)
# [2023-09-09
# 21:51:49]
# Fetching
# org.eclipse.tm.terminal.feature_11.2.0.202303131754.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/features/
# (21.36kB)
# [2023-09-09
# 21:51:49]
# Downloading
# org.eclipse.tips.feature
# [2023-09-09
# 21:51:49]
# Fetching
# org.eclipse.ecf.core.feature_1.6.1.v20230507-1923.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (21.56kB)
# [2023-09-09
# 21:51:49]
# Fetching
# org.eclipse.ecf.core.ssl.feature_1.1.501.v20230507-1921.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (21.52kB)
# [2023-09-09
# 21:51:49]
# Downloading
# org.eclipse.tips.json
# [2023-09-09
# 21:51:49]
# Fetching
# org.eclipse.tips.json_0.3.0.v20230317-0802.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (21.71kB)
# [2023-09-09
# 21:51:49]
# Downloading
# org.eclipse.m2e.logback
# [2023-09-09
# 21:51:49]
# Downloading
# org.eclipse.platform
# [2023-09-09
# 21:51:49]
# Fetching
# org.eclipse.help_2.3.1400.v20230605-0440.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (21.32kB)
# [2023-09-09
# 21:51:50]
# Fetching
# org.eclipse.platform_4.28.0.v20230605-0440.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (22.28kB)
# [2023-09-09
# 21:51:50]
# Downloading
# org.eclipse.eclemma.feature
# [2023-09-09
# 21:51:50]
# Downloading
# org.eclipse.mylyn.hudson.ui
# [2023-09-09
# 21:51:50]
# Fetching
# org.eclipse.m2e.logback_2.1.200.20230523-2106.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (21.96kB)
# [2023-09-09
# 21:51:50]
# Fetching
# org.eclipse.tips.feature_0.4.0.v20230429-1617.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/features/
# (21.64kB)
# [2023-09-09
# 21:51:50]
# Downloading
# org.eclipse.e4.rcp
# [2023-09-09
# 21:51:50]
# Downloading
# org.eclipse.e4.ui.workbench3
# [2023-09-09
# 21:51:50]
# Fetching
# org.eclipse.eclemma.feature_3.1.7.202306070845.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (22.3kB)
# [2023-09-09
# 21:51:50]
# Downloading
# org.eclipse.mylyn.git.ui
# [2023-09-09
# 21:51:50]
# Downloading
# org.eclipse.m2e.binaryproject
# [2023-09-09
# 21:51:50]
# Fetching
# org.eclipse.mylyn.hudson.ui_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (22.34kB)
# [2023-09-09
# 21:51:50]
# Downloading
# junit-platform-suite-engine
# [2023-09-09
# 21:51:50]
# Fetching
# org.eclipse.e4.ui.workbench3_0.17.0.v20230317-0802.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (22.89kB)
# [2023-09-09
# 21:51:50]
# Downloading
# org.eclipse.m2e.profiles.core
# [2023-09-09
# 21:51:50]
# Downloading
# org.eclipse.mylyn.java.tasks
# [2023-09-09
# 21:51:51]
# Fetching
# junit-platform-suite-engine_1.9.3.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (23.55kB)
# [2023-09-09
# 21:51:51]
# Downloading
# org.eclipse.mylyn.git.core
# [2023-09-09
# 21:51:51]
# Fetching
# org.eclipse.mylyn.java.tasks_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (24.1kB)
# [2023-09-09
# 21:51:51]
# Fetching
# org.eclipse.mylyn.git.ui_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (23.14kB)
# [2023-09-09
# 21:51:51]
# Downloading
# org.eclipse.ui.win32
# [2023-09-09
# 21:51:51]
# Downloading
# org.eclipse.ecf.provider.filetransfer.httpclient5.win32
# [2023-09-09
# 21:51:51]
# Fetching
# org.eclipse.e4.rcp_4.28.0.v20230525-0648.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/features/
# (22.74kB)
# [2023-09-09
# 21:51:51]
# Fetching
# org.eclipse.mylyn.git.core_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (24.2kB)
# [2023-09-09
# 21:51:51]
# Downloading
# org.eclipse.tm.terminal.connector.local.feature
# [2023-09-09
# 21:51:51]
# Fetching
# org.eclipse.ui.win32_3.5.0.v20230317-0802.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (24.25kB)
# [2023-09-09
# 21:51:51]
# Downloading
# org.eclipse.tm.terminal.connector.telnet.feature
# [2023-09-09
# 21:51:51]
# Fetching
# org.eclipse.m2e.profiles.core_2.1.200.20230520-0934.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (23.64kB)
# [2023-09-09
# 21:51:51]
# Fetching
# org.eclipse.m2e.binaryproject_2.1.200.20230520-0934.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (23.3kB)
# [2023-09-09
# 21:51:51]
# Downloading
# org.eclipse.ecf.filetransfer.ssl.feature
# [2023-09-09
# 21:51:51]
# Fetching
# org.eclipse.tm.terminal.connector.telnet.feature_11.2.0.202303140100.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (24.99kB)
# [2023-09-09
# 21:51:51]
# Downloading
# org.eclipse.ui.intro.quicklinks
# [2023-09-09
# 21:51:51]
# Downloading
# org.eclipse.mylyn.egit.ui
# [2023-09-09
# 21:51:51]
# Downloading
# org.eclipse.e4.ui.services
# [2023-09-09
# 21:51:51]
# Fetching
# org.eclipse.ui.intro.quicklinks_1.2.0.v20230429-1610.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (25.6kB)
# [2023-09-09
# 21:51:51]
# Downloading
# org.eclipse.equinox.p2.garbagecollector
# [2023-09-09
# 21:51:51]
# Fetching
# org.eclipse.tm.terminal.connector.local.feature_11.2.0.202303140100.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (24.97kB)
# [2023-09-09
# 21:51:51]
# Downloading
# junit-jupiter-migrationsupport
# [2023-09-09
# 21:51:52]
# Downloading
# org.eclipse.jgit.http.apache
# [2023-09-09
# 21:51:52]
# Fetching
# org.eclipse.ecf.provider.filetransfer.httpclient5.win32_1.1.0.v20230423-0417.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (24.79kB)
# [2023-09-09
# 21:51:52]
# Fetching
# org.eclipse.ecf.filetransfer.ssl.feature_1.1.401.v20230422-0242.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (25.56kB)
# [2023-09-09
# 21:51:52]
# Fetching
# org.eclipse.jgit.http.apache_6.6.0.202305301015-r.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (27.13kB)
# [2023-09-09
# 21:51:52]
# Fetching
# org.eclipse.mylyn.egit.ui_3.26.1.v20230531-0547.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (26.1kB)
# [2023-09-09
# 21:51:52]
# Downloading
# org.eclipse.core.net.win32
# [2023-09-09
# 21:51:52]
# Downloading
# org.eclipse.jgit.archive
# [2023-09-09
# 21:51:52]
# Downloading
# org.eclipse.m2e.sourcelookup.ui
# [2023-09-09
# 21:51:52]
# Downloading
# org.eclipse.mylyn.ide.ant
# [2023-09-09
# 21:51:52]
# Fetching
# junit-jupiter-migrationsupport_5.9.3.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (27.04kB)
# [2023-09-09
# 21:51:52]
# Fetching
# org.eclipse.core.net.win32_1.1.0.v20230317-0901.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (27.54kB)
# [2023-09-09
# 21:51:52]
# Fetching
# org.eclipse.jgit.archive_6.6.0.202305301015-r.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (27.66kB)
# [2023-09-09
# 21:51:52]
# Downloading
# org.eclipse.e4.core.commands
# [2023-09-09
# 21:51:52]
# Downloading
# org.eclipse.ecf.filetransfer.feature
# [2023-09-09
# 21:51:52]
# Fetching
# org.eclipse.m2e.sourcelookup.ui_2.0.300.20230520-0934.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (27.81kB)
# [2023-09-09
# 21:51:52]
# Downloading
# org.eclipse.ecf.filetransfer.httpclient5.feature
# [2023-09-09
# 21:51:52]
# Downloading
# org.eclipse.e4.ui.css.swt.theme
# [2023-09-09
# 21:51:52]
# Fetching
# org.eclipse.e4.ui.services_1.6.0.v20230501-1823.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (26.28kB)
# [2023-09-09
# 21:51:52]
# Downloading
# org.eclipse.equinox.p2.console
# [2023-09-09
# 21:51:52]
# Fetching
# org.eclipse.equinox.p2.garbagecollector_1.3.0.v20230322-1009.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (26.86kB)
# [2023-09-09
# 21:51:52]
# Fetching
# org.eclipse.e4.core.commands_1.1.0.v20230501-1823.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (28.32kB)
# [2023-09-09
# 21:51:52]
# Fetching
# org.eclipse.ecf.filetransfer.httpclient5.feature_1.1.701.v20230423-0417.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (29.69kB)
# [2023-09-09
# 21:51:52]
# Fetching
# org.eclipse.e4.ui.css.swt.theme_0.14.0.v20230501-1533.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (29.97kB)
# [2023-09-09
# 21:51:52]
# Downloading
# org.eclipse.m2e.mavenarchiver
# [2023-09-09
# 21:51:52]
# Downloading
# org.eclipse.mylyn.tasks.index.ui
# [2023-09-09
# 21:51:53]
# Fetching
# org.eclipse.m2e.mavenarchiver_2.0.400.20230520-0934.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (31.06kB)
# [2023-09-09
# 21:51:53]
# Fetching
# org.eclipse.ecf.filetransfer.feature_3.14.1800.v20230422-0242.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/
# (29.65kB)
# [2023-09-09
# 21:51:53]
# Downloading
# org.eclipse.mylyn.commons.notifications.feed
# [2023-09-09
# 21:51:53]
# Fetching
# org.eclipse.mylyn.ide.ant_3.26.1.v20230604-1755.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (28.16kB)
# [2023-09-09
# 21:51:53]
# Downloading
# org.eclipse.jface.notifications
# [2023-09-09
# 21:51:53]
# Fetching
# org.eclipse.mylyn.ide.ant_3.26.1.v20230604-1755.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (28.16kB)
# [2023-09-09
# 21:51:53]
# Fetching
# org.eclipse.mylyn.tasks.index.ui_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (31.92kB)
# [2023-09-09
# 21:51:53]
# Fetching
# org.eclipse.jface.notifications_0.6.0.v20230317-0802.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (32.89kB)
# [2023-09-09
# 21:51:53]
# Fetching
# org.eclipse.equinox.p2.console_1.3.0.v20230330-0930.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (30.32kB)
# [2023-09-09
# 21:51:53]
# Downloading
# org.eclipse.mylyn.versions.core
# [2023-09-09
# 21:51:53]
# Fetching
# org.eclipse.mylyn.commons.notifications.feed_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (32.86kB)
# [2023-09-09
# 21:51:53]
# Downloading
# org.eclipse.equinox.p2.directorywatcher
# [2023-09-09
# 21:51:53]
# Downloading
# org.glassfish.hk2.osgi-resource-locator
# [2023-09-09
# 21:51:53]
# Fetching
# org.eclipse.mylyn.versions.core_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (32.93kB)
# [2023-09-09
# 21:51:53]
# Downloading
# org.eclipse.mylyn.tasks.index.core
# [2023-09-09
# 21:51:53]
# Downloading
# org.eclipse.tm4e.registry
# [2023-09-09
# 21:51:53]
# Downloading
# org.eclipse.mylyn.ide.ui
# [2023-09-09
# 21:51:53]
# Fetching
# org.eclipse.equinox.p2.directorywatcher_1.4.0.v20230330-0930.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (33.48kB)
# [2023-09-09
# 21:51:53]
# Downloading
# org.eclipse.mylyn.commons.activity.ui
# [2023-09-09
# 21:51:54]
# Fetching
# org.eclipse.mylyn.ide.ui_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (37.29kB)
# [2023-09-09
# 21:51:54]
# Downloading
# org.eclipse.equinox.p2.extensionlocation
# [2023-09-09
# 21:51:54]
# Downloading
# org.eclipse.core.variables
# [2023-09-09
# 21:51:54]
# Downloading
# org.eclipse.mylyn.commons.repositories.http.core
# [2023-09-09
# 21:51:54]
# Fetching
# org.glassfish.hk2.osgi-resource-locator_2.5.0.v20161103-1916.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (33.49kB)
# [2023-09-09
# 21:51:54]
# Fetching
# org.eclipse.equinox.p2.extensionlocation_1.5.0.v20230330-0930.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (37.44kB)
# [2023-09-09
# 21:51:54]
# Fetching
# org.eclipse.mylyn.tasks.index.core_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (34.7kB)
# [2023-09-09
# 21:51:54]
# Downloading
# org.eclipse.mylyn.debug.ui
# [2023-09-09
# 21:51:54]
# Downloading
# org.eclipse.jgit.ssh.apache.agent
# [2023-09-09
# 21:51:54]
# Fetching
# org.eclipse.mylyn.commons.activity.ui_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (37.31kB)
# [2023-09-09
# 21:51:54]
# Downloading
# org.eclipse.equinox.p2.discovery
# [2023-09-09
# 21:51:54]
# Fetching
# org.eclipse.mylyn.debug.ui_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (38.5kB)
# [2023-09-09
# 21:51:54]
# Fetching
# org.eclipse.tm4e.registry_0.6.3.202303141648.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (36.48kB)
# [2023-09-09
# 21:51:54]
# Fetching
# org.eclipse.jgit.ssh.apache.agent_6.6.0.202305301015-r.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (39.66kB)
# [2023-09-09
# 21:51:54]
# Downloading
# org.eclipse.mylyn.monitor.core
# [2023-09-09
# 21:51:54]
# Downloading
# org.eclipse.jdt.apt.pluggable.core
# [2023-09-09
# 21:51:54]
# Fetching
# org.eclipse.jdt.apt.pluggable.core_1.4.0.v20230323-1537.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (41.69kB)
# [2023-09-09
# 21:51:55]
# Downloading
# org.eclipse.nebula.widgets.tablecombo
# [2023-09-09
# 21:51:55]
# Downloading
# org.eclipse.e4.core.di.extensions.supplier
# [2023-09-09
# 21:51:55]
# Fetching
# org.eclipse.core.variables_3.6.0.v20230317-0802.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (37.44kB)
# [2023-09-09
# 21:51:55]
# Fetching
# org.eclipse.mylyn.commons.repositories.http.core_3.26.1.v20230604-1755.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (38.12kB)
# [2023-09-09
# 21:51:55]
# Downloading
# org.eclipse.m2e.profiles.ui
# [2023-09-09
# 21:51:55]
# Fetching
# org.eclipse.mylyn.monitor.core_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (40.66kB)
# [2023-09-09
# 21:51:55]
# Downloading
# org.eclipse.core.externaltools
# [2023-09-09
# 21:51:55]
# Fetching
# org.eclipse.equinox.p2.discovery_1.3.0.v20230322-1009.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (39.85kB)
# [2023-09-09
# 21:51:55]
# Fetching
# org.eclipse.e4.core.di.extensions.supplier_0.17.0.v20230429-1914.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (42.27kB)
# [2023-09-09
# 21:51:55]
# Downloading
# org.eclipse.jsch.core
# [2023-09-09
# 21:51:55]
# Downloading
# org.eclipse.tm.terminal.view.core
# [2023-09-09
# 21:51:55]
# Fetching
# org.eclipse.nebula.widgets.tablecombo_1.2.0.202305300939.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (41.98kB)
# [2023-09-09
# 21:51:55]
# Fetching
# org.eclipse.jsch.core_1.5.0.v20230317-0901.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (43.19kB)
# [2023-09-09
# 21:51:55]
# Downloading
# org.eclipse.jdt
# [2023-09-09
# 21:51:55]
# Downloading
# org.eclipse.m2e.apt.ui
# [2023-09-09
# 21:51:56]
# Fetching
# org.eclipse.m2e.profiles.ui_2.0.300.20230520-0934.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (42.7kB)
# [2023-09-09
# 21:51:56]
# Fetching
# org.eclipse.tm.terminal.view.core_4.9.100.202303140100.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (44.19kB)
# [2023-09-09
# 21:51:56]
# Fetching
# org.eclipse.m2e.apt.ui_2.0.400.20230520-0934.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (44.91kB)
# [2023-09-09
# 21:51:56]
# Downloading
# org.eclipse.compare.win32
# [2023-09-09
# 21:51:56]
# Downloading
# org.eclipse.mylyn.commons.identity.core
# [2023-09-09
# 21:51:56]
# Downloading
# org.eclipse.ui.net
# [2023-09-09
# 21:51:56]
# Downloading
# org.eclipse.equinox.p2.transport.ecf
# [2023-09-09
# 21:51:56]
# Fetching
# org.eclipse.core.externaltools_1.3.0.v20230317-0802.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (42.7kB)
# [2023-09-09
# 21:51:56]
# Downloading
# javax.annotation
# [2023-09-09
# 21:51:56]
# Fetching
# org.eclipse.equinox.p2.transport.ecf_1.4.0.v20230415-1327.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (47.97kB)
# [2023-09-09
# 21:51:56]
# Fetching
# org.eclipse.jdt_3.19.100.v20230605-0440.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (44.73kB)
# [2023-09-09
# 21:51:56]
# Fetching
# org.eclipse.compare.win32_1.3.0.v20230317-0901.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (46.18kB)
# [2023-09-09
# 21:51:56]
# Fetching
# org.eclipse.mylyn.commons.identity.core_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (47kB)
# [2023-09-09
# 21:51:56]
# Downloading
# org.eclipse.e4.ui.bindings
# [2023-09-09
# 21:51:56]
# Fetching
# org.eclipse.ui.net_1.5.0.v20230317-0901.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (47.76kB)
# [2023-09-09
# 21:51:56]
# Downloading
# org.eclipse.core.net
# [2023-09-09
# 21:51:57]
# Downloading
# org.eclipse.mylyn.commons.repositories.core
# [2023-09-09
# 21:51:57]
# Downloading
# org.eclipse.equinox.p2.reconciler.dropins
# [2023-09-09
# 21:51:57]
# Fetching
# org.eclipse.equinox.p2.reconciler.dropins_1.5.0.v20230330-0930.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (51.45kB)
# [2023-09-09
# 21:51:57]
# Fetching
# javax.annotation_1.3.5.v20230504-0748.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (48.11kB)
# [2023-09-09
# 21:51:57]
# Fetching
# org.eclipse.e4.ui.bindings_0.14.0.v20230501-1823.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (48.17kB)
# [2023-09-09
# 21:51:57]
# Downloading
# org.eclipse.e4.emf.xpath
# [2023-09-09
# 21:51:57]
# Fetching
# org.eclipse.core.net_1.5.0.v20230317-0901.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (49.44kB)
# [2023-09-09
# 21:51:57]
# Downloading
# org.eclipse.mylyn.monitor.ui
# [2023-09-09
# 21:51:58]
# Fetching
# org.eclipse.mylyn.commons.repositories.core_3.26.1.v20230604-1755.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (50.21kB)
# [2023-09-09
# 21:51:58]
# Downloading
# org.eclipse.urischeme
# [2023-09-09
# 21:51:58]
# Downloading
# org.eclipse.e4.core.di
# [2023-09-09
# 21:51:58]
# Fetching
# org.eclipse.e4.emf.xpath_0.4.0.v20230317-0802.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (52.84kB)
# [2023-09-09
# 21:51:58]
# Downloading
# org.eclipse.ecf.discovery
# [2023-09-09
# 21:51:58]
# Downloading
# org.eclipse.e4.core.contexts
# [2023-09-09
# 21:51:58]
# Downloading
# org.apache.commons.cli
# [2023-09-09
# 21:51:58]
# Fetching
# org.eclipse.mylyn.monitor.ui_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (53.45kB)
# [2023-09-09
# 21:51:58]
# Fetching
# org.eclipse.urischeme_1.3.0.v20230317-0802.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (53.7kB)
# [2023-09-09
# 21:51:58]
# Fetching
# org.eclipse.e4.core.di_1.9.0.v20230429-1914.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (54.33kB)
# [2023-09-09
# 21:51:58]
# Downloading
# org.eclipse.e4.ui.dialogs
# [2023-09-09
# 21:51:58]
# Downloading
# org.eclipse.oomph.predicates.edit
# [2023-09-09
# 21:51:59]
# Downloading
# org.eclipse.equinox.p2.discovery.compatibility
# [2023-09-09
# 21:51:59]
# Fetching
# org.eclipse.ecf.discovery_5.1.2.v20230528-2254.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (55.95kB)
# [2023-09-09
# 21:51:59]
# Fetching
# org.eclipse.e4.core.contexts_1.12.0.v20230510-1240.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (56.42kB)
# [2023-09-09
# 21:51:59]
# Fetching
# org.apache.commons.cli_1.5.0.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (56.92kB)
# [2023-09-09
# 21:51:59]
# Fetching
# org.eclipse.oomph.predicates.edit_1.15.0.v20230416-0642.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (59.04kB)
# [2023-09-09
# 21:51:59]
# Downloading
# org.eclipse.equinox.p2.director.app
# [2023-09-09
# 21:51:59]
# Fetching
# org.eclipse.equinox.p2.discovery.compatibility_1.3.0.v20230322-1009.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (60.43kB)
# [2023-09-09
# 21:51:59]
# Fetching
# org.eclipse.e4.ui.dialogs_1.4.0.v20230317-0802.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (58.53kB)
# [2023-09-09
# 21:51:59]
# Downloading
# org.eclipse.ui.monitoring
# [2023-09-09
# 21:51:59]
# Downloading
# org.eclipse.tm.terminal.connector.ssh
# [2023-09-09
# 21:51:59]
# Downloading
# org.eclipse.mylyn.commons.notifications.ui
# [2023-09-09
# 21:51:59]
# Downloading
# org.eclipse.equinox.p2.jarprocessor
# [2023-09-09
# 21:52:00]
# Fetching
# org.eclipse.ui.monitoring_1.3.0.v20230317-0802.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (61.72kB)
# [2023-09-09
# 21:52:00]
# Downloading
# org.eclipse.m2e.apt.core
# [2023-09-09
# 21:52:00]
# Fetching
# org.eclipse.equinox.p2.director.app_1.3.0.v20230330-0930.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (61.66kB)
# [2023-09-09
# 21:52:00]
# Fetching
# org.eclipse.mylyn.commons.notifications.ui_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (63.4kB)
# [2023-09-09
# 21:52:00]
# Downloading
# junit-vintage-engine
# [2023-09-09
# 21:52:00]
# Downloading
# org.eclipse.jgit.gpg.bc
# [2023-09-09
# 21:52:00]
# Fetching
# org.eclipse.tm.terminal.connector.ssh_4.8.100.202303140100.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (62.03kB)
# [2023-09-09
# 21:52:00]
# Fetching
# junit-vintage-engine_5.9.3.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (65.33kB)
# [2023-09-09
# 21:52:00]
# Fetching
# org.eclipse.jgit.gpg.bc_6.6.0.202305301015-r.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (66.11kB)
# [2023-09-09
# 21:52:00]
# Downloading
# org.eclipse.ecf.identity
# [2023-09-09
# 21:52:00]
# Fetching
# org.eclipse.m2e.apt.core_2.2.100.20230520-0934.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (65.27kB)
# [2023-09-09
# 21:52:00]
# Fetching
# org.eclipse.equinox.p2.jarprocessor_1.3.0.v20230330-1254.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (63.57kB)
# [2023-09-09
# 21:52:00]
# Fetching
# org.eclipse.ecf.identity_3.10.0.v20230422-0242.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (67.72kB)
# [2023-09-09
# 21:52:00]
# Downloading
# org.eclipse.compare.core
# [2023-09-09
# 21:52:00]
# Downloading
# org.eclipse.tips.ui
# [2023-09-09
# 21:52:01]
# Downloading
# org.eclipse.cdt.core.native
# [2023-09-09
# 21:52:01]
# Downloading
# org.eclipse.mylyn.resources.ui
# [2023-09-09
# 21:52:01]
# Downloading
# org.eclipse.mylyn.tasks.search
# [2023-09-09
# 21:52:01]
# Downloading
# org.eclipse.equinox.frameworkadmin.equinox
# [2023-09-09
# 21:52:01]
# Fetching
# org.eclipse.mylyn.resources.ui_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (70.34kB)
# [2023-09-09
# 21:52:01]
# Downloading
# org.eclipse.e4.core.services
# [2023-09-09
# 21:52:01]
# Fetching
# org.eclipse.mylyn.tasks.search_3.26.1.v20230604-1755.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (70.8kB)
# [2023-09-09
# 21:52:01]
# Downloading
# org.eclipse.core.filesystem
# [2023-09-09
# 21:52:01]
# Downloading
# org.eclipse.jdt.apt.ui
# [2023-09-09
# 21:52:01]
# Downloading
# org.eclipse.core.runtime
# [2023-09-09
# 21:52:01]
# Fetching
# org.eclipse.compare.core_3.8.0.v20230517-1315.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (69.26kB)
# [2023-09-09
# 21:52:01]
# Downloading
# org.eclipse.mylyn.github.core
# [2023-09-09
# 21:52:01]
# Fetching
# org.eclipse.cdt.core.native_6.3.200.202303140100.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (70.09kB)
# [2023-09-09
# 21:52:01]
# Fetching
# org.eclipse.tips.ui_0.3.0.v20230317-0802.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (69.32kB)
# [2023-09-09
# 21:52:01]
# Fetching
# org.eclipse.core.filesystem_1.10.0.v20230425-0513.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (71.88kB)
# [2023-09-09
# 21:52:01]
# Downloading
# org.eclipse.equinox.p2.operations
# [2023-09-09
# 21:52:01]
# Fetching
# org.eclipse.jdt.apt.ui_3.8.0.v20230323-1537.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (73.78kB)
# [2023-09-09
# 21:52:02]
# Fetching
# org.eclipse.equinox.frameworkadmin.equinox_1.2.300.v20230320-0659.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (70.94kB)
# [2023-09-09
# 21:52:02]
# Fetching
# org.eclipse.equinox.p2.operations_2.7.0.v20230322-1009.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (77.31kB)
# [2023-09-09
# 21:52:02]
# Fetching
# org.eclipse.core.runtime_3.27.0.v20230515-1719.jar
# from
# https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/
# (74.42kB)
# [2023-09-09
# 21:52:02]
# Fetching
# org.eclipse.e4.core.services_2.4.0.v20230429-1914.jar
# from
# https://download.eclipse.org/releases/2023-06/202306141000/plugins/
# (71.48kB)
# [2023-09-09
# 21:52:02]
# Downloading
# org.eclipse.equinox.p2.core
# [2023-09-09
# 21:52:02]
# Fetching
# org.eclipse.mylyn.github.core_6.2.1.v20230531-0547.jar
# from
# https://download.eclipse.org/releases/2023-06/202306141000/plugins/
# (76.45kB)
# [2023-09-09
# 21:52:02]
# Downloading
# org.eclipse.equinox.p2.ui.sdk
# [2023-09-09
# 21:52:03]
# Downloading
# com.ibm.icu
# [2023-09-09
# 21:52:03]
# Fetching
# org.eclipse.equinox.p2.core_2.10.0.v20230330-0930.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (79.47kB)
# [2023-09-09
# 21:52:03]
# Downloading
# org.eclipse.jdt.ui
# [2023-09-09
# 21:52:03]
# Downloading
# org.eclipse.wildwebdeveloper.xml
# [2023-09-09
# 21:52:03]
# Downloading
# org.eclipse.jdt.doc.user
# [2023-09-09
# 21:52:03]
# Fetching
# org.eclipse.equinox.p2.ui.sdk_1.3.0.v20230507-1427.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (80.71kB)
# [2023-09-09
# 21:52:03]
# Downloading
# org.eclipse.m2e.maven.runtime
# [2023-09-09
# 21:52:03]
# Fetching
# com.ibm.icu_73.1.0.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (13.89MB)
# [2023-09-09
# 21:52:03]
# Downloading
# org.eclipse.egit.doc
# [2023-09-09
# 21:52:03]
# Fetching
# org.eclipse.jdt.ui_3.29.0.v20230525-0728.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (10.97MB)
# [2023-09-09
# 21:52:03]
# Downloading
# org.eclipse.platform.doc.user
# [2023-09-09
# 21:52:04]
# Fetching
# org.eclipse.m2e.maven.runtime_3.9.100.20230519-1558.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (7.65MB)
# [2023-09-09
# 21:52:04]
# Downloading
# org.eclipse.jdt.core
# [2023-09-09
# 21:52:04]
# Downloading
# org.eclipse.egit.ui
# [2023-09-09
# 21:52:04]
# Fetching
# com.ibm.icu_73.1.0.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# [2023-09-09
# 21:52:04]
# Fetching
# org.eclipse.jdt.ui_3.29.0.v20230525-0728.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# [2023-09-09
# 21:52:04]
# Fetching
# org.eclipse.platform.doc.user_4.28.0.v20230601-1614.jar
# from
# https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/
# (4.21MB)
# [2023-09-09
# 21:52:05]
# Downloading
# org.apache.lucene.core
# ...
# 21:53:41]
# Installing
# org.eclipse.oomph.p2.ui
# [1.21.0.v20230828-1517]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.predicates
# [1.17.0.v20230617-1322]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.predicates.edit
# [1.15.0.v20230416-0642]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.preferences
# [1.14.0.v20230617-1322]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.resources
# [1.18.0.v20230617-1322]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.resources.edit
# [1.13.0.v20230204-0932]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.setup
# [1.27.0.v20230714-1137]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.setup.core
# [1.28.0.v20230618-0610]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.setup.core.feature.group
# [1.28.0.v20230817-0718]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.setup.core.feature.jar
# [1.28.0.v20230817-0718]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.setup.doc
# [1.14.0.v20230618-0610]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.setup.edit
# [1.16.0.v20220421-1218]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.setup.editor
# [1.26.0.v20230828-1517]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.setup.feature.group
# [1.29.0.v20230828-1517]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.setup.feature.jar
# [1.29.0.v20230828-1517]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.setup.p2
# [1.20.0.v20230617-1322]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.setup.p2.edit
# [1.16.0.v20230617-1322]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.setup.sync
# [1.14.0.v20220421-1218]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.setup.ui
# [1.27.0.v20230828-1517]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.setup.ui.questionnaire
# [1.13.0.v20220421-1218]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.ui
# [1.20.0.v20230828-1517]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.util
# [1.20.0.v20230620-1408]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.workingsets
# [1.14.0.v20230617-1322]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.workingsets.edit
# [1.13.0.v20230204-0932]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.oomph.workingsets.editor
# [1.15.0.v20230828-1517]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.osgi
# [3.18.400.v20230509-2241]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.osgi.compatibility.state
# [1.2.800.v20221116-1440]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.osgi.services
# [3.11.100.v20221006-1531]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.osgi.util
# [3.7.200.v20230103-1101]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.platform
# [4.28.0.v20230605-0440]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.platform.doc.user
# [4.28.0.v20230601-1614]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.platform.feature.group
# [4.28.0.v20230605-0440]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.platform.feature.jar
# [4.28.0.v20230605-0440]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.platform_root
# [4.28.0.v20230605-0440]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.rcp
# [4.28.0.v20230605-0440]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.rcp.feature.group
# [4.28.0.v20230605-0440]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.rcp.feature.jar
# [4.28.0.v20230605-0440]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.rcp_root
# [4.28.0.v20230605-0440]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.search
# [3.15.0.v20230427-2049]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.swt
# [3.124.0.v20230523-1044]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.swt.win32.win32.x86_64
# [3.124.0.v20230523-1044]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.team.core
# [3.10.0.v20230317-0901]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.team.genericeditor.diff.extension
# [1.2.0.v20230317-0901]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.team.ui
# [3.10.0.v20230317-0901]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.text
# [3.13.0.v20230316-1200]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.text.quicksearch
# [1.2.100.v20230427-1010]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tips.core
# [0.3.0.v20230317-0802]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tips.feature.feature.group
# [0.4.0.v20230429-1617]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tips.feature.feature.jar
# [0.4.0.v20230429-1617]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tips.ide
# [0.3.0.v20230429-1617]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tips.json
# [0.3.0.v20230317-0802]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tips.ui
# [0.3.0.v20230317-0802]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.connector.local
# [4.8.0.202211062329]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.connector.local.feature.feature.group
# [11.2.0.202303140100]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.connector.local.feature.feature.jar
# [11.2.0.202303140100]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.connector.process
# [4.9.0.202211062329]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.connector.ssh
# [4.8.100.202303140100]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.connector.ssh.feature.feature.group
# [11.2.0.202303140100]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.connector.ssh.feature.feature.jar
# [11.2.0.202303140100]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.connector.telnet
# [4.8.0.202211062329]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.connector.telnet.feature.feature.group
# [11.2.0.202303140100]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.connector.telnet.feature.feature.jar
# [11.2.0.202303140100]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.control
# [5.4.100.202303140100]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.control.feature.feature.group
# [11.2.0.202303140100]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.control.feature.feature.jar
# [11.2.0.202303140100]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.feature.feature.group
# [11.2.0.202303131754]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.feature.feature.jar
# [11.2.0.202303131754]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.view.core
# [4.9.100.202303140100]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.view.feature.feature.group
# [11.2.0.202304132101]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.view.feature.feature.jar
# [11.2.0.202304132101]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm.terminal.view.ui
# [4.11.100.202304132101]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm4e.core
# [0.5.4.202305171341]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm4e.languageconfiguration
# [0.5.5.202305171341]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm4e.registry
# [0.6.3.202303141648]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.tm4e.ui
# [0.6.4.202305161247]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui
# [3.203.100.v20230417-1307]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.browser
# [3.8.0.v20230329-1440]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.cheatsheets
# [3.8.0.v20230317-0802]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.console
# [3.12.0.v20230317-0802]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.editors
# [3.16.0.v20230329-1609]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.externaltools
# [3.6.0.v20230317-0802]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.forms
# [3.12.0.v20230317-0802]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.genericeditor
# [1.3.0.v20230516-1137]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.ide
# [3.21.0.v20230526-1500]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.ide.application
# [1.5.0.v20230526-1051]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.intro
# [3.7.0.v20230503-0628]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.intro.quicklinks
# [1.2.0.v20230429-1610]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.intro.universal
# [3.5.0.v20230317-0802]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.monitoring
# [1.3.0.v20230317-0802]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.navigator
# [3.12.0.v20230329-1313]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.navigator.resources
# [3.9.0.v20230317-0802]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.net
# [1.5.0.v20230317-0901]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.themes
# [1.2.2200.v20230220-0932]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.views
# [3.12.0.v20230317-0802]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.views.log
# [1.4.0.v20230418-0745]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.views.properties.tabbed
# [3.10.0.v20230317-0802]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.win32
# [3.5.0.v20230317-0802]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.workbench
# [3.129.0.v20230525-0648]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.ui.workbench.texteditor
# [3.17.0.v20230316-1200]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.update.configurator
# [3.5.0.v20230317-0901]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.urischeme
# [1.3.0.v20230317-0802]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.userstorage
# [1.2.0.v20210517-0327]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.userstorage.feature.group
# [1.2.0.v20210517-0327]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.userstorage.feature.jar
# [1.2.0.v20210517-0327]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.userstorage.oauth
# [1.1.0.v20190307-0457]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.userstorage.ui
# [1.1.0.v20190307-0457]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.wildwebdeveloper.xml
# [1.1.0.202304242122]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.wildwebdeveloper.xml.feature.feature.group
# [1.1.0.202304242122]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.wildwebdeveloper.xml.feature.feature.jar
# [1.1.0.202304242122]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.wst.common.core
# [1.4.100.v202103232321]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.wst.common.emf
# [1.2.700.v202007161535]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.wst.common.environment
# [1.0.401.v202007142017]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.wst.common.frameworks
# [1.2.202.v202108200212]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.wst.common.uriresolver
# [1.3.0.v202007161535]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.wst.sse.core
# [1.2.1100.v202305221405]
# [2023-09-09
# 21:53:41]
# Installing
# org.eclipse.wst.xml.core
# [1.2.700.v202305221615]
# [2023-09-09
# 21:53:41]
# Installing
# org.glassfish.hk2.osgi-resource-locator
# [2.5.0.v20161103-1916]
# [2023-09-09
# 21:53:41]
# Installing
# org.gradle.toolingapi
# [8.1.1.v20230428-1350]
# [2023-09-09
# 21:53:41]
# Installing
# org.hamcrest.core
# [1.3.0.v20180420-1519]
# [2023-09-09
# 21:53:41]
# Installing
# org.jacoco.agent
# [0.8.10.202304240956]
# [2023-09-09
# 21:53:41]
# Installing
# org.jacoco.core
# [0.8.10.202304240956]
# [2023-09-09
# 21:53:41]
# Installing
# org.jacoco.report
# [0.8.10.202304240956]
# [2023-09-09
# 21:53:41]
# Installing
# org.jcodings
# [1.0.58]
# [2023-09-09
# 21:53:41]
# Installing
# org.joni
# [2.1.48]
# [2023-09-09
# 21:53:41]
# Installing
# org.jsoup
# [1.15.3]
# [2023-09-09
# 21:53:41]
# Installing
# org.junit
# [4.13.2.v20211018-1956]
# [2023-09-09
# 21:53:41]
# Installing
# org.objectweb.asm
# [9.5.0]
# [2023-09-09
# 21:53:41]
# Installing
# org.objectweb.asm.commons
# [9.5.0]
# [2023-09-09
# 21:53:41]
# Installing
# org.objectweb.asm.tree
# [9.5.0]
# [2023-09-09
# 21:53:41]
# Installing
# org.objectweb.asm.tree.analysis
# [9.5.0]
# [2023-09-09
# 21:53:41]
# Installing
# org.objectweb.asm.util
# [9.5.0]
# [2023-09-09
# 21:53:41]
# Installing
# org.opentest4j
# [1.2.0]
# [2023-09-09
# 21:53:41]
# Installing
# org.osgi.service.cm
# [1.6.1.202109301733]
# [2023-09-09
# 21:53:41]
# Installing
# org.osgi.service.component
# [1.5.1.202212101352]
# [2023-09-09
# 21:53:41]
# Installing
# org.osgi.service.device
# [1.1.1.202109301733]
# [2023-09-09
# 21:53:41]
# Installing
# org.osgi.service.event
# [1.4.1.202109301733]
# [2023-09-09
# 21:53:41]
# Installing
# org.osgi.service.metatype
# [1.4.1.202109301733]
# [2023-09-09
# 21:53:41]
# Installing
# org.osgi.service.prefs
# [1.1.2.202109301733]
# [2023-09-09
# 21:53:41]
# Installing
# org.osgi.service.provisioning
# [1.2.0.201505202024]
# [2023-09-09
# 21:53:41]
# Installing
# org.osgi.service.upnp
# [1.2.1.202109301733]
# [2023-09-09
# 21:53:41]
# Installing
# org.osgi.service.useradmin
# [1.1.1.202109301733]
# [2023-09-09
# 21:53:41]
# Installing
# org.osgi.service.wireadmin
# [1.0.2.202109301733]
# [2023-09-09
# 21:53:41]
# Installing
# org.osgi.util.function
# [1.2.0.202109301733]
# [2023-09-09
# 21:53:41]
# Installing
# org.osgi.util.measurement
# [1.0.2.201802012109]
# [2023-09-09
# 21:53:41]
# Installing
# org.osgi.util.position
# [1.0.1.201505202026]
# [2023-09-09
# 21:53:41]
# Installing
# org.osgi.util.promise
# [1.3.0.202212101352]
# [2023-09-09
# 21:53:41]
# Installing
# org.osgi.util.xml
# [1.0.2.202109301733]
# [2023-09-09
# 21:53:41]
# Installing
# org.sat4j.core
# [2.3.6.v20201214]
# [2023-09-09
# 21:53:41]
# Installing
# org.sat4j.pb
# [2.3.6.v20201214]
# [2023-09-09
# 21:53:41]
# Installing
# org.slf4j.api
# [1.7.30.v20221112-0806]
# [2023-09-09
# 21:53:41]
# Installing
# org.tukaani.xz
# [1.9.0]
# [2023-09-09
# 21:53:41]
# Installing
# org.w3c.css.sac
# [1.3.1.v200903091627]
# [2023-09-09
# 21:53:41]
# Installing
# org.w3c.dom.events
# [3.0.0.draft20060413_v201105210656]
# [2023-09-09
# 21:53:41]
# Installing
# org.w3c.dom.smil
# [1.0.1.v200903091627]
# [2023-09-09
# 21:53:41]
# Installing
# org.w3c.dom.svg
# [1.1.0.v201011041433]
# [2023-09-09
# 21:53:41]
# Installing
# org.yaml.snakeyaml
# [1.27.0.v20221112-0806]
# [2023-09-09
# 21:53:41]
# Installing
# slf4j.api
# [2.0.7]
# [2023-09-09
# 21:53:41]
# Installing
# slf4j.nop
# [2.0.7]
# [2023-09-09
# 21:53:41]
# Installing
# tooling.org.eclipse.update.feature.default
# [1.0.0]
# [2023-09-09
# 21:53:41]
# Installing
# tooling.osgi.bundle.default
# [1.0.0]
# [2023-09-09
# 21:53:41]
# Installing
# tooling.source.default
# [1.0.0]
# [2023-09-09
# 21:53:41]
# Installing
# toolingepp.package.java.application
# [4.28.0.20230608-1200]
# [2023-09-09
# 21:53:41]
# Installing
# toolingepp.package.java.config.win32.win32.x86_64
# [4.28.0.20230608-1200]
# [2023-09-09
# 21:53:41]
# Installing
# toolingepp.package.java.configuration
# [4.28.0.20230608-1200]
# [2023-09-09
# 21:53:41]
# Installing
# toolingepp.package.java.executable.win32.win32.x86_64
# [4.28.0.20230608-1200]
# [2023-09-09
# 21:53:41]
# Installing
# toolingepp.package.java.ini.win32.win32.x86_64
# [4.28.0.20230608-1200]
# [2023-09-09
# 21:53:41]
# Installing
# toolingorg.eclipse.epp.java.configuration
# [1.0.0]
# [2023-09-09
# 21:53:41]
# Installing
# toolingorg.eclipse.equinox.launcher
# [1.6.400.v20210924-0641]
# [2023-09-09
# 21:53:41]
# Installing
# toolingorg.eclipse.equinox.launcher.win32.win32.x86_64
# [1.2.700.v20221108-1024]
# [2023-09-09
# 21:53:41]
# Installing
# toolingwin32.win32.x86_64org.apache.felix.scr
# [4.28.0.20230608-1200]
# [2023-09-09
# 21:53:41]
# Installing
# toolingwin32.win32.x86_64org.eclipse.core.runtime
# [4.28.0.20230608-1200]
# [2023-09-09
# 21:53:41]
# Installing
# toolingwin32.win32.x86_64org.eclipse.equinox.common
# [4.28.0.20230608-1200]
# [2023-09-09
# 21:53:41]
# Installing
# toolingwin32.win32.x86_64org.eclipse.equinox.event
# [4.28.0.20230608-1200]
# [2023-09-09
# 21:53:41]
# Installing
# toolingwin32.win32.x86_64org.eclipse.equinox.p2.reconciler.dropins
# [4.28.0.20230608-1200]
# [2023-09-09
# 21:53:41]
# Installing
# toolingwin32.win32.x86_64org.eclipse.equinox.simpleconfigurator
# [4.28.0.20230608-1200]
# [2023-09-09
# 21:53:42]
# Preparing
# to
# commit
# the
# provisioning
# operation.
# [2023-09-09
# 21:53:42]
# Committing
# the
# provisioning
# operation.
# [2023-09-09
# 21:53:43]
# Performing
# Eclipse
# Ini
# --launcher.appendVmargs
# [2023-09-09
# 21:53:43]
# Performing
# Eclipse
# Ini
# -Declipse.p2.max.threads=10
# [2023-09-09
# 21:53:43]
# Changing
# C:\Users\eluri\eclipse\java-2023-06\eclipse\eclipse.ini
# (-Declipse.p2.max.threads=10)
# [2023-09-09
# 21:53:43]
# Performing
# Eclipse
# Ini
# -Doomph.update.url=https://download.eclipse.org/oomph/updates/milestone/latest
# [2023-09-09
# 21:53:43]
# Changing
# C:\Users\eluri\eclipse\java-2023-06\eclipse\eclipse.ini
# (-Doomph.update.url=https://download.eclipse.org/oomph/updates/milestone/latest)
# [2023-09-09
# 21:53:43]
# Performing
# Eclipse
# Ini
# -Doomph.redirection.index.redirection=index:/->http://git.eclipse.org/c/oomph/org.eclipse.oomph.git/plain/setups/
# [2023-09-09
# 21:53:43]
# Changing
# C:\Users\eluri\eclipse\java-2023-06\eclipse\eclipse.ini
# (-Doomph.redirection.index.redirection=index:/->http://git.eclipse.org/c/oomph/org.eclipse.oomph.git/plain/setups/)
# [2023-09-09
# 21:53:43]
# Performing
# post
# bootstrap
# tasks
# [2023-09-09
# 21:53:43]

# %%
#ii. For each word in the input file, calculate the length of the word and store it

# %%
log_file_path = "D:\practise\logfile.txt"  
word_lengths = {} 

try:
    with open('D:\practise\logfile.txt', 'r') as log_file:
        log_content = log_file.read()
        words = log_content.split()
        for word in words:
            word_lengths[word] = len(word)
        for word, length in word_lengths.items():
            print(f"Word: {word}, Length: {length}")
except FileNotFoundError:
    print(f"The file '{log_file_path}' was not found.")
except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# Word: [2023-09-09, Length: 11
# Word: 21:51:29], Length: 9
# Word: Executing, Length: 9
# Word: bootstrap, Length: 9
# Word: tasks, Length: 5
# Word: OpenJDK, Length: 7
# Word: Runtime, Length: 7
# Word: Environment, Length: 11
# Word: 17.0.7+7, Length: 8
# Word: Product, Length: 7
# Word: org.eclipse.products.epp.package.java.2023-06, Length: 45
# Word: Bundle, Length: 6
# Word: org.eclipse.oomph.setup, Length: 23
# Word: 1.26.0.v20230416-0656,, Length: 22
# Word: build=5945,, Length: 11
# Word: branch=c5558820f367665758d4d719b7553a02ff4954e0, Length: 47
# Word: org.eclipse.oomph.setup.core, Length: 28
# Word: 1.27.0.v20230402-0730,, Length: 22
# Word: org.eclipse.oomph.setup.p2, Length: 26
# Word: 1.19.0.v20230416-1150,, Length: 22
# Word: Performing, Length: 10
# Word: P2, Length: 2
# Word: Director, Length: 8
# Word: (Eclipse, Length: 8
# Word: IDE, Length: 3
# Word: for, Length: 3
# Word: Java, Length: 4
# Word: Developers, Length: 10
# Word: (2023-06)), Length: 10
# Word: Offline, Length: 7
# Word: =, Length: 1
# Word: false, Length: 5
# Word: Mirrors, Length: 7
# Word: true, Length: 4
# Word: Resolving, Length: 9
# Word: 26, Length: 2
# Word: requirements, Length: 12
# Word: from, Length: 4
# Word: 3, Length: 1
# Word: repositories, Length: 12
# Word: to, Length: 2
# Word: C:\Users\eluri\eclipse\java-2023-06\eclipse, Length: 43
# Word: Requirement, Length: 11
# Word: org.eclipse.equinox.p2.iu:epp.package.java, Length: 42
# Word: [4.28.0,5.0.0), Length: 14
# Word: (filter=(|(&(osgi.arch=aarch64)(osgi.os=linux)(osgi.ws=gtk))(&(osgi.arch=aarch64)(osgi.os=macosx)(osgi.ws=cocoa))(&(osgi.arch=x86_64)(osgi.os=linux)(osgi.ws=gtk))(&(osgi.arch=x86_64)(osgi.os=macosx)(osgi.ws=cocoa))(&(osgi.arch=x86_64)(osgi.os=win32)(osgi.ws=win32)))), Length: 267
# Word: org.eclipse.equinox.p2.iu:org.eclipse.platform.feature.group, Length: 60
# Word: org.eclipse.equinox.p2.iu:org.eclipse.rcp.feature.group, Length: 55
# Word: org.eclipse.equinox.p2.iu:org.eclipse.buildship.feature.group, Length: 61
# Word: org.eclipse.equinox.p2.iu:org.eclipse.eclemma.feature.feature.group, Length: 67
# Word: org.eclipse.equinox.p2.iu:org.eclipse.egit.feature.group, Length: 56
# Word: org.eclipse.equinox.p2.iu:org.eclipse.epp.mpc.feature.group, Length: 59
# Word: org.eclipse.equinox.p2.iu:org.eclipse.jdt.bcoview.feature.feature.group, Length: 71
# Word: org.eclipse.equinox.p2.iu:org.eclipse.jdt.feature.group, Length: 55
# Word: org.eclipse.equinox.p2.iu:org.eclipse.jgit.feature.group, Length: 56
# Word: org.eclipse.equinox.p2.iu:org.eclipse.m2e.feature.feature.group, Length: 63
# Word: org.eclipse.equinox.p2.iu:org.eclipse.m2e.lemminx.feature.feature.group, Length: 71
# Word: org.eclipse.equinox.p2.iu:org.eclipse.m2e.logback.feature.feature.group, Length: 71
# Word: org.eclipse.equinox.p2.iu:org.eclipse.mylyn.commons.activity.feature.group, Length: 74
# Word: org.eclipse.equinox.p2.iu:org.eclipse.mylyn.egit.feature.feature.group, Length: 70
# Word: org.eclipse.equinox.p2.iu:org.eclipse.mylyn.git.feature.group, Length: 61
# Word: org.eclipse.equinox.p2.iu:org.eclipse.mylyn.github.feature.feature.group, Length: 72
# Word: org.eclipse.equinox.p2.iu:org.eclipse.mylyn.hudson.feature.group, Length: 64
# Word: org.eclipse.equinox.p2.iu:org.eclipse.mylyn.ide_feature.feature.group, Length: 69
# Word: org.eclipse.equinox.p2.iu:org.eclipse.mylyn.java_feature.feature.group, Length: 70
# Word: org.eclipse.equinox.p2.iu:org.eclipse.mylyn.reviews.feature.feature.group, Length: 73
# Word: org.eclipse.equinox.p2.iu:org.eclipse.mylyn.wikitext_feature.feature.group, Length: 74
# Word: org.eclipse.equinox.p2.iu:org.eclipse.tips.feature.feature.group, Length: 64
# Word: org.eclipse.equinox.p2.iu:org.eclipse.tm.terminal.feature.feature.group, Length: 71
# Word: org.eclipse.equinox.p2.iu:org.eclipse.wildwebdeveloper.xml.feature.feature.group, Length: 80
# Word: org.eclipse.equinox.p2.iu:org.eclipse.oomph.setup.feature.group, Length: 63
# Word: Repository, Length: 10
# Word: https://download.eclipse.org/technology/epp/packages/2023-06/202306081200, Length: 73
# Word: https://download.eclipse.org/releases/2023-06/202306141000, Length: 58
# Word: https://download.eclipse.org/oomph/updates/milestone/latest, Length: 59
# Word: 21:51:36], Length: 9
# Word: Calculating, Length: 11
# Word: and, Length: 3
# Word: dependencies., Length: 13
# Word: Computing, Length: 9
# Word: prerequisite, Length: 12
# Word: plan, Length: 4
# Word: 21:51:39], Length: 9
# Word: Collecting, Length: 10
# Word: 351, Length: 3
# Word: artifacts, Length: 9
# Word: 21:51:41], Length: 9
# Word: Downloading, Length: 11
# Word: org.eclipse.platform_root, Length: 25
# Word: org.eclipse.jdt.core.formatterapp, Length: 33
# Word: org.eclipse.e4.core.di.extensions, Length: 33
# Word: org.eclipse.egit, Length: 16
# Word: org.eclipse.rcp, Length: 15
# Word: org.eclipse.core.net.win32.x86_64, Length: 33
# Word: org.eclipse.ecf.provider.filetransfer.ssl, Length: 41
# Word: org.eclipse.e4.ui.swt.win32, Length: 27
# Word: org.eclipse.e4.ui.ide, Length: 21
# Word: org.eclipse.e4.core.di.annotations, Length: 34
# Word: 21:51:42], Length: 9
# Word: Fetching, Length: 8
# Word: org.eclipse.ecf.provider.filetransfer.ssl_1.1.0.v20230422-0242.jar, Length: 66
# Word: https://mirrors.jevincanders.net/eclipse/releases/2023-06/202306141000/plugins/, Length: 79
# Word: (11.58kB), Length: 9
# Word: org.eclipse.platform_root_4.28.0.v20230605-0440, Length: 47
# Word: https://mirror.umd.edu/eclipse/releases/2023-06/202306141000/binary/, Length: 68
# Word: (196B), Length: 6
# Word: junit-platform-suite-commons, Length: 28
# Word: org.eclipse.jdt.core.formatterapp_1.2.0.v20230323-1537.jar, Length: 58
# Word: https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/plugins/, Length: 80
# Word: (14.43kB), Length: 9
# Word: org.eclipse.e4.ui.swt.win32_1.2.0.v20230501-1823.jar, Length: 52
# Word: https://mirrors.xmission.com/eclipse/releases/2023-06/202306141000/plugins/, Length: 75
# Word: (12.12kB), Length: 9
# Word: 21:51:43], Length: 9
# Word: org.eclipse.e4.core.di.extensions_0.18.0.v20230429-1914.jar, Length: 59
# Word: https://ftp.fau.de/eclipse/releases/2023-06/202306141000/plugins/, Length: 65
# Word: (12.92kB), Length: 9
# Word: org.eclipse.e4.ui.widgets, Length: 25
# Word: org.eclipse.egit_6.6.0.202305301015-r.jar, Length: 41
# Word: https://mirror.csclub.uwaterloo.ca/eclipse/releases/2023-06/202306141000/plugins/, Length: 81
# Word: (13.13kB), Length: 9
# Word: org.eclipse.m2e.sourcelookup, Length: 28
# Word: org.eclipse.e4.ui.ide_3.17.0.v20230317-0802.jar, Length: 47
# Word: https://mirror.clarkson.edu/eclipse/releases/2023-06/202306141000/plugins/, Length: 74
# Word: (13.31kB), Length: 9
# Word: org.eclipse.rcp_4.28.0.v20230605-0440.jar, Length: 41
# Word: https://ftp2.osuosl.org/pub/eclipse/releases/2023-06/202306141000/plugins/, Length: 74
# Word: (12.91kB), Length: 9
# Word: org.eclipse.e4.core.di.annotations_1.8.0.v20230429-1914.jar, Length: 59
# Word: https://eclipse.mirror.rafal.ca/releases/2023-06/202306141000/plugins/, Length: 70
# Word: (13.81kB), Length: 9
# Word: junit-platform-suite-commons_1.9.3.jar, Length: 38
# Word: https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/plugins/, Length: 71
# Word: (14.94kB), Length: 9
# Word: org.eclipse.mylyn.versions.ui, Length: 29
# Word: org.eclipse.core.net.win32.x86_64_1.2.0.v20230317-0901.jar, Length: 58
# Word: https://mirror.ibcp.fr/pub/eclipse/releases/2023-06/202306141000/plugins/, Length: 73
# Word: (9.59kB), Length: 8
# Word: org.eclipse.m2e.sourcelookup_2.0.300.20230520-0934.jar, Length: 54
# Word: (15.21kB), Length: 9
# Word: org.eclipse.mylyn.versions.ui_3.26.1.v20230604-1755.jar, Length: 55
# Word: (15.37kB), Length: 9
# Word: 21:51:44], Length: 9
# Word: org.eclipse.mylyn.commons.notifications.core, Length: 44
# Word: org.eclipse.jgit, Length: 16
# Word: junit-platform-runner, Length: 21
# Word: org.eclipse.jgit.gpg.bc, Length: 23
# Word: org.eclipse.jgit.http.apache, Length: 28
# Word: org.eclipse.jgit.ssh.apache, Length: 27
# Word: org.eclipse.buildship.compat, Length: 28
# Word: org.eclipse.e4.ui.widgets_1.4.0.v20230317-0802.jar, Length: 50
# Word: https://download.eclipse.org/releases/2023-06/202306141000/plugins/, Length: 67
# Word: (15.11kB), Length: 9
# Word: org.eclipse.jgit_6.6.0.202305301015-r.jar, Length: 41
# Word: https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/features/, Length: 72
# Word: (16.17kB), Length: 9
# Word: junit-platform-runner_1.9.3.jar, Length: 31
# Word: (16.19kB), Length: 9
# Word: org.eclipse.mylyn.commons.notifications.core_3.26.1.v20230604-1755.jar, Length: 70
# Word: (16.02kB), Length: 9
# Word: org.eclipse.jgit.gpg.bc_6.6.0.202305301015-r.jar, Length: 48
# Word: (16.2kB), Length: 8
# Word: org.eclipse.buildship.branding, Length: 30
# Word: org.eclipse.team.genericeditor.diff.extension, Length: 45
# Word: org.eclipse.e4.ui.di, Length: 20
# Word: org.eclipse.m2e.binaryproject.ui, Length: 32
# Word: org.eclipse.swt, Length: 15
# Word: org.eclipse.team.genericeditor.diff.extension_1.2.0.v20230317-0901.jar, Length: 70
# Word: (18.13kB), Length: 9
# Word: org.eclipse.buildship.branding_3.1.7.v20230428-1350.jar, Length: 55
# Word: (17.43kB), Length: 9
# Word: 21:51:45], Length: 9
# Word: org.eclipse.ecf.ssl, Length: 19
# Word: org.eclipse.equinox.p2.updatechecker, Length: 36
# Word: org.eclipse.e4.ui.di_1.5.0.v20230501-1823.jar, Length: 45
# Word: (18.17kB), Length: 9
# Word: org.eclipse.jgit.http.apache_6.6.0.202305301015-r.jar, Length: 53
# Word: https://ftp.acc.umu.se/mirror/eclipse.org/releases/2023-06/202306141000/features/, Length: 81
# Word: (16.21kB), Length: 9
# Word: org.eclipse.m2e.binaryproject.ui_2.0.100.20230520-0934.jar, Length: 58
# Word: (18.78kB), Length: 9
# Word: org.eclipse.rcp_root, Length: 20
# Word: org.eclipse.jgit.ssh.apache_6.6.0.202305301015-r.jar, Length: 52
# Word: org.eclipse.ecf.ssl_1.3.0.v20230507-1921.jar, Length: 44
# Word: (19.13kB), Length: 9
# Word: org.eclipse.equinox.p2.updatechecker_1.4.0.v20230330-0930.jar, Length: 61
# Word: (20.11kB), Length: 9
# Word: org.eclipse.buildship.compat_3.1.7.v20230428-1350.jar, Length: 53
# Word: (16.94kB), Length: 9
# Word: org.eclipse.buildship, Length: 21
# Word: org.eclipse.wildwebdeveloper.xml.feature, Length: 40
# Word: org.eclipse.jdt.bcoview.feature, Length: 31
# Word: junit-platform-suite-api, Length: 24
# Word: org.eclipse.equinox.p2.user.ui, Length: 30
# Word: org.eclipse.rcp_root_4.28.0.v20230605-0440, Length: 42
# Word: https://mirror.dogado.de/eclipse/releases/2023-06/202306141000/binary/, Length: 70
# Word: (20.24kB), Length: 9
# Word: org.eclipse.swt_3.124.0.v20230523-1044.jar, Length: 42
# Word: org.eclipse.buildship_3.1.7.v20230428-1350.jar, Length: 46
# Word: (20.47kB), Length: 9
# Word: org.eclipse.wildwebdeveloper.xml.feature_1.1.0.202304242122.jar, Length: 63
# Word: (20.5kB), Length: 8
# Word: org.eclipse.mylyn.github.feature, Length: 32
# Word: org.eclipse.jdt.bcoview.feature_1.2.0.v20230323-1830.jar, Length: 56
# Word: (20.63kB), Length: 9
# Word: org.eclipse.mylyn.github.feature_6.2.1.v20230531-0547.jar, Length: 57
# Word: (20.78kB), Length: 9
# Word: 21:51:46], Length: 9
# Word: org.eclipse.mylyn.monitor, Length: 25
# Word: org.eclipse.mylyn.discovery, Length: 27
# Word: org.eclipse.mylyn.commons.identity, Length: 34
# Word: org.eclipse.mylyn.monitor_3.26.1.v20230604-1755.jar, Length: 51
# Word: (20.79kB), Length: 9
# Word: org.eclipse.mylyn.discovery_3.26.1.v20230604-1755.jar, Length: 53
# Word: org.eclipse.m2e.lemminx.feature, Length: 31
# Word: junit-platform-suite-api_1.9.3.jar, Length: 34
# Word: (20.73kB), Length: 9
# Word: org.eclipse.mylyn.commons, Length: 25
# Word: org.eclipse.mylyn.tasks.ide, Length: 27
# Word: org.eclipse.mylyn.commons.identity_3.26.1.v20230604-1755.jar, Length: 60
# Word: org.eclipse.equinox.p2.user.ui_2.4.2000.v20230510-1208.jar, Length: 58
# Word: (20.75kB), Length: 9
# Word: org.eclipse.mylyn.team_feature, Length: 30
# Word: org.eclipse.m2e.logback.feature, Length: 31
# Word: org.eclipse.m2e.lemminx.feature_2.0.4.20230520-0934.jar, Length: 55
# Word: (20.82kB), Length: 9
# Word: org.eclipse.mylyn.commons_3.26.1.v20230604-1755.jar, Length: 51
# Word: org.eclipse.mylyn.tasks.ide_3.26.1.v20230604-1755.jar, Length: 53
# Word: (20.83kB), Length: 9
# Word: org.eclipse.mylyn.team_feature_3.26.1.v20230604-1755.jar, Length: 56
# Word: org.eclipse.mylyn.commons.activity, Length: 34
# Word: 21:51:47], Length: 9
# Word: org.eclipse.equinox.p2.discovery.feature, Length: 40
# Word: org.eclipse.mylyn.versions, Length: 26
# Word: org.eclipse.mylyn.commons.repositories.http, Length: 43
# Word: org.eclipse.mylyn.reviews.feature, Length: 33
# Word: org.eclipse.mylyn.builds, Length: 24
# Word: org.eclipse.mylyn.git, Length: 21
# Word: org.eclipse.mylyn.context_feature, Length: 33
# Word: org.eclipse.mylyn.commons.activity_3.26.1.v20230604-1755.jar, Length: 60
# Word: (20.84kB), Length: 9
# Word: org.eclipse.mylyn.ide_feature, Length: 29
# Word: org.eclipse.mylyn.commons.repositories.http_3.26.1.v20230604-1755.jar, Length: 69
# Word: (20.85kB), Length: 9
# Word: org.eclipse.mylyn.reviews.feature_3.26.1.v20230604-1755.jar, Length: 59
# Word: org.eclipse.mylyn.context_feature_3.26.1.v20230604-1755.jar, Length: 59
# Word: (20.86kB), Length: 9
# Word: org.eclipse.mylyn.commons.repositories, Length: 38
# Word: org.eclipse.equinox.p2.rcp.feature, Length: 34
# Word: org.eclipse.mylyn.commons.notifications, Length: 39
# Word: org.eclipse.mylyn.ide_feature_3.26.1.v20230604-1755.jar, Length: 55
# Word: org.eclipse.mylyn.hudson, Length: 24
# Word: org.eclipse.m2e.logback.feature_2.1.2.20230523-2106.jar, Length: 55
# Word: org.eclipse.mylyn.commons.notifications_3.26.1.v20230604-1755.jar, Length: 65
# Word: (20.87kB), Length: 9
# Word: org.eclipse.equinox.p2.extras.feature, Length: 37
# Word: org.eclipse.mylyn.commons.repositories_3.26.1.v20230604-1755.jar, Length: 64
# Word: org.eclipse.equinox.p2.rcp.feature_1.4.2000.v20230510-1208.jar, Length: 62
# Word: org.eclipse.mylyn.versions_3.26.1.v20230604-1755.jar, Length: 52
# Word: org.eclipse.mylyn.hudson_3.26.1.v20230604-1755.jar, Length: 50
# Word: (20.9kB), Length: 8
# Word: 21:51:48], Length: 9
# Word: org.eclipse.equinox.p2.discovery.feature_1.3.0.v20230322-1009.jar, Length: 65
# Word: org.eclipse.mylyn.java_feature, Length: 30
# Word: org.eclipse.mylyn.builds_3.26.1.v20230604-1755.jar, Length: 50
# Word: (20.92kB), Length: 9
# Word: org.eclipse.mylyn.egit.feature, Length: 30
# Word: org.eclipse.tm.terminal.control.feature, Length: 39
# Word: org.eclipse.mylyn.java_feature_3.26.1.v20230604-1755.jar, Length: 56
# Word: (20.96kB), Length: 9
# Word: org.eclipse.tm.terminal.view.feature, Length: 36
# Word: org.eclipse.tm.terminal.connector.ssh.feature, Length: 45
# Word: org.eclipse.mylyn.egit.feature_3.26.1.v20230531-0547.jar, Length: 56
# Word: (21.13kB), Length: 9
# Word: org.eclipse.m2e.feature, Length: 23
# Word: org.eclipse.help, Length: 16
# Word: org.eclipse.mylyn.git_3.26.1.v20230604-1755.jar, Length: 47
# Word: https://download.eclipse.org/releases/2023-06/202306141000/features/, Length: 68
# Word: org.eclipse.tm.terminal.feature, Length: 31
# Word: org.eclipse.tm.terminal.connector.ssh.feature_11.2.0.202303140100.jar, Length: 69
# Word: (21.24kB), Length: 9
# Word: org.eclipse.tm.terminal.view.feature_11.2.0.202304132101.jar, Length: 60
# Word: (21.22kB), Length: 9
# Word: org.eclipse.mylyn_feature, Length: 25
# Word: org.eclipse.equinox.p2.core.feature, Length: 35
# Word: (20.95kB), Length: 9
# Word: org.eclipse.mylyn_feature_3.26.1.v20230604-1755.jar, Length: 51
# Word: (21.42kB), Length: 9
# Word: org.eclipse.m2e.feature_2.3.0.20230523-2033.jar, Length: 47
# Word: (21.26kB), Length: 9
# Word: org.eclipse.jdt, Length: 15
# Word: 21:51:49], Length: 9
# Word: org.eclipse.ecf.core.ssl.feature, Length: 32
# Word: org.eclipse.equinox.p2.core.feature_1.6.1800.v20230509-1332.jar, Length: 63
# Word: (21.47kB), Length: 9
# Word: org.eclipse.tm.terminal.control.feature_11.2.0.202303140100.jar, Length: 63
# Word: (21.19kB), Length: 9
# Word: org.eclipse.equinox.p2.extras.feature_1.4.2000.v20230509-1332.jar, Length: 65
# Word: org.eclipse.ecf.core.feature, Length: 28
# Word: org.eclipse.jdt_3.19.100.v20230605-0440.jar, Length: 43
# Word: (21.51kB), Length: 9
# Word: org.eclipse.tm.terminal.feature_11.2.0.202303131754.jar, Length: 55
# Word: (21.36kB), Length: 9
# Word: org.eclipse.tips.feature, Length: 24
# Word: org.eclipse.ecf.core.feature_1.6.1.v20230507-1923.jar, Length: 53
# Word: (21.56kB), Length: 9
# Word: org.eclipse.ecf.core.ssl.feature_1.1.501.v20230507-1921.jar, Length: 59
# Word: (21.52kB), Length: 9
# Word: org.eclipse.tips.json, Length: 21
# Word: org.eclipse.tips.json_0.3.0.v20230317-0802.jar, Length: 46
# Word: (21.71kB), Length: 9
# Word: org.eclipse.m2e.logback, Length: 23
# Word: org.eclipse.platform, Length: 20
# Word: org.eclipse.help_2.3.1400.v20230605-0440.jar, Length: 44
# Word: (21.32kB), Length: 9
# Word: 21:51:50], Length: 9
# Word: org.eclipse.platform_4.28.0.v20230605-0440.jar, Length: 46
# Word: (22.28kB), Length: 9
# Word: org.eclipse.eclemma.feature, Length: 27
# Word: org.eclipse.mylyn.hudson.ui, Length: 27
# Word: org.eclipse.m2e.logback_2.1.200.20230523-2106.jar, Length: 49
# Word: (21.96kB), Length: 9
# Word: org.eclipse.tips.feature_0.4.0.v20230429-1617.jar, Length: 49
# Word: (21.64kB), Length: 9
# Word: org.eclipse.e4.rcp, Length: 18
# Word: org.eclipse.e4.ui.workbench3, Length: 28
# Word: org.eclipse.eclemma.feature_3.1.7.202306070845.jar, Length: 50
# Word: (22.3kB), Length: 8
# Word: org.eclipse.mylyn.git.ui, Length: 24
# Word: org.eclipse.m2e.binaryproject, Length: 29
# Word: org.eclipse.mylyn.hudson.ui_3.26.1.v20230604-1755.jar, Length: 53
# Word: (22.34kB), Length: 9
# Word: junit-platform-suite-engine, Length: 27
# Word: org.eclipse.e4.ui.workbench3_0.17.0.v20230317-0802.jar, Length: 54
# Word: (22.89kB), Length: 9
# Word: org.eclipse.m2e.profiles.core, Length: 29
# Word: org.eclipse.mylyn.java.tasks, Length: 28
# Word: 21:51:51], Length: 9
# Word: junit-platform-suite-engine_1.9.3.jar, Length: 37
# Word: (23.55kB), Length: 9
# Word: org.eclipse.mylyn.git.core, Length: 26
# Word: org.eclipse.mylyn.java.tasks_3.26.1.v20230604-1755.jar, Length: 54
# Word: (24.1kB), Length: 8
# Word: org.eclipse.mylyn.git.ui_3.26.1.v20230604-1755.jar, Length: 50
# Word: (23.14kB), Length: 9
# Word: org.eclipse.ui.win32, Length: 20
# Word: org.eclipse.ecf.provider.filetransfer.httpclient5.win32, Length: 55
# Word: org.eclipse.e4.rcp_4.28.0.v20230525-0648.jar, Length: 44
# Word: (22.74kB), Length: 9
# Word: org.eclipse.mylyn.git.core_3.26.1.v20230604-1755.jar, Length: 52
# Word: (24.2kB), Length: 8
# Word: org.eclipse.tm.terminal.connector.local.feature, Length: 47
# Word: org.eclipse.ui.win32_3.5.0.v20230317-0802.jar, Length: 45
# Word: (24.25kB), Length: 9
# Word: org.eclipse.tm.terminal.connector.telnet.feature, Length: 48
# Word: org.eclipse.m2e.profiles.core_2.1.200.20230520-0934.jar, Length: 55
# Word: (23.64kB), Length: 9
# Word: org.eclipse.m2e.binaryproject_2.1.200.20230520-0934.jar, Length: 55
# Word: (23.3kB), Length: 8
# Word: org.eclipse.ecf.filetransfer.ssl.feature, Length: 40
# Word: org.eclipse.tm.terminal.connector.telnet.feature_11.2.0.202303140100.jar, Length: 72
# Word: (24.99kB), Length: 9
# Word: org.eclipse.ui.intro.quicklinks, Length: 31
# Word: org.eclipse.mylyn.egit.ui, Length: 25
# Word: org.eclipse.e4.ui.services, Length: 26
# Word: org.eclipse.ui.intro.quicklinks_1.2.0.v20230429-1610.jar, Length: 56
# Word: (25.6kB), Length: 8
# Word: org.eclipse.equinox.p2.garbagecollector, Length: 39
# Word: org.eclipse.tm.terminal.connector.local.feature_11.2.0.202303140100.jar, Length: 71
# Word: (24.97kB), Length: 9
# Word: junit-jupiter-migrationsupport, Length: 30
# Word: 21:51:52], Length: 9
# Word: org.eclipse.ecf.provider.filetransfer.httpclient5.win32_1.1.0.v20230423-0417.jar, Length: 80
# Word: (24.79kB), Length: 9
# Word: org.eclipse.ecf.filetransfer.ssl.feature_1.1.401.v20230422-0242.jar, Length: 67
# Word: (25.56kB), Length: 9
# Word: (27.13kB), Length: 9
# Word: org.eclipse.mylyn.egit.ui_3.26.1.v20230531-0547.jar, Length: 51
# Word: (26.1kB), Length: 8
# Word: org.eclipse.core.net.win32, Length: 26
# Word: org.eclipse.jgit.archive, Length: 24
# Word: org.eclipse.m2e.sourcelookup.ui, Length: 31
# Word: org.eclipse.mylyn.ide.ant, Length: 25
# Word: junit-jupiter-migrationsupport_5.9.3.jar, Length: 40
# Word: (27.04kB), Length: 9
# Word: org.eclipse.core.net.win32_1.1.0.v20230317-0901.jar, Length: 51
# Word: (27.54kB), Length: 9
# Word: org.eclipse.jgit.archive_6.6.0.202305301015-r.jar, Length: 49
# Word: (27.66kB), Length: 9
# Word: org.eclipse.e4.core.commands, Length: 28
# Word: org.eclipse.ecf.filetransfer.feature, Length: 36
# Word: org.eclipse.m2e.sourcelookup.ui_2.0.300.20230520-0934.jar, Length: 57
# Word: (27.81kB), Length: 9
# Word: org.eclipse.ecf.filetransfer.httpclient5.feature, Length: 48
# Word: org.eclipse.e4.ui.css.swt.theme, Length: 31
# Word: org.eclipse.e4.ui.services_1.6.0.v20230501-1823.jar, Length: 51
# Word: (26.28kB), Length: 9
# Word: org.eclipse.equinox.p2.console, Length: 30
# Word: org.eclipse.equinox.p2.garbagecollector_1.3.0.v20230322-1009.jar, Length: 64
# Word: (26.86kB), Length: 9
# Word: org.eclipse.e4.core.commands_1.1.0.v20230501-1823.jar, Length: 53
# Word: (28.32kB), Length: 9
# Word: org.eclipse.ecf.filetransfer.httpclient5.feature_1.1.701.v20230423-0417.jar, Length: 75
# Word: (29.69kB), Length: 9
# Word: org.eclipse.e4.ui.css.swt.theme_0.14.0.v20230501-1533.jar, Length: 57
# Word: (29.97kB), Length: 9
# Word: org.eclipse.m2e.mavenarchiver, Length: 29
# Word: org.eclipse.mylyn.tasks.index.ui, Length: 32
# Word: 21:51:53], Length: 9
# Word: org.eclipse.m2e.mavenarchiver_2.0.400.20230520-0934.jar, Length: 55
# Word: (31.06kB), Length: 9
# Word: org.eclipse.ecf.filetransfer.feature_3.14.1800.v20230422-0242.jar, Length: 65
# Word: (29.65kB), Length: 9
# Word: org.eclipse.mylyn.commons.notifications.feed, Length: 44
# Word: org.eclipse.mylyn.ide.ant_3.26.1.v20230604-1755.jar, Length: 51
# Word: (28.16kB), Length: 9
# Word: org.eclipse.jface.notifications, Length: 31
# Word: org.eclipse.mylyn.tasks.index.ui_3.26.1.v20230604-1755.jar, Length: 58
# Word: (31.92kB), Length: 9
# Word: org.eclipse.jface.notifications_0.6.0.v20230317-0802.jar, Length: 56
# Word: (32.89kB), Length: 9
# Word: org.eclipse.equinox.p2.console_1.3.0.v20230330-0930.jar, Length: 55
# Word: (30.32kB), Length: 9
# Word: org.eclipse.mylyn.versions.core, Length: 31
# Word: org.eclipse.mylyn.commons.notifications.feed_3.26.1.v20230604-1755.jar, Length: 70
# Word: (32.86kB), Length: 9
# Word: org.eclipse.equinox.p2.directorywatcher, Length: 39
# Word: org.glassfish.hk2.osgi-resource-locator, Length: 39
# Word: org.eclipse.mylyn.versions.core_3.26.1.v20230604-1755.jar, Length: 57
# Word: (32.93kB), Length: 9
# Word: org.eclipse.mylyn.tasks.index.core, Length: 34
# Word: org.eclipse.tm4e.registry, Length: 25
# Word: org.eclipse.mylyn.ide.ui, Length: 24
# Word: org.eclipse.equinox.p2.directorywatcher_1.4.0.v20230330-0930.jar, Length: 64
# Word: (33.48kB), Length: 9
# Word: org.eclipse.mylyn.commons.activity.ui, Length: 37
# Word: 21:51:54], Length: 9
# Word: org.eclipse.mylyn.ide.ui_3.26.1.v20230604-1755.jar, Length: 50
# Word: (37.29kB), Length: 9
# Word: org.eclipse.equinox.p2.extensionlocation, Length: 40
# Word: org.eclipse.core.variables, Length: 26
# Word: org.eclipse.mylyn.commons.repositories.http.core, Length: 48
# Word: org.glassfish.hk2.osgi-resource-locator_2.5.0.v20161103-1916.jar, Length: 64
# Word: (33.49kB), Length: 9
# Word: org.eclipse.equinox.p2.extensionlocation_1.5.0.v20230330-0930.jar, Length: 65
# Word: (37.44kB), Length: 9
# Word: org.eclipse.mylyn.tasks.index.core_3.26.1.v20230604-1755.jar, Length: 60
# Word: (34.7kB), Length: 8
# Word: org.eclipse.mylyn.debug.ui, Length: 26
# Word: org.eclipse.jgit.ssh.apache.agent, Length: 33
# Word: org.eclipse.mylyn.commons.activity.ui_3.26.1.v20230604-1755.jar, Length: 63
# Word: (37.31kB), Length: 9
# Word: org.eclipse.equinox.p2.discovery, Length: 32
# Word: org.eclipse.mylyn.debug.ui_3.26.1.v20230604-1755.jar, Length: 52
# Word: (38.5kB), Length: 8
# Word: org.eclipse.tm4e.registry_0.6.3.202303141648.jar, Length: 48
# Word: (36.48kB), Length: 9
# Word: org.eclipse.jgit.ssh.apache.agent_6.6.0.202305301015-r.jar, Length: 58
# Word: (39.66kB), Length: 9
# Word: org.eclipse.mylyn.monitor.core, Length: 30
# Word: org.eclipse.jdt.apt.pluggable.core, Length: 34
# Word: org.eclipse.jdt.apt.pluggable.core_1.4.0.v20230323-1537.jar, Length: 59
# Word: (41.69kB), Length: 9
# Word: 21:51:55], Length: 9
# Word: org.eclipse.nebula.widgets.tablecombo, Length: 37
# Word: org.eclipse.e4.core.di.extensions.supplier, Length: 42
# Word: org.eclipse.core.variables_3.6.0.v20230317-0802.jar, Length: 51
# Word: org.eclipse.mylyn.commons.repositories.http.core_3.26.1.v20230604-1755.jar, Length: 74
# Word: (38.12kB), Length: 9
# Word: org.eclipse.m2e.profiles.ui, Length: 27
# Word: org.eclipse.mylyn.monitor.core_3.26.1.v20230604-1755.jar, Length: 56
# Word: (40.66kB), Length: 9
# Word: org.eclipse.core.externaltools, Length: 30
# Word: org.eclipse.equinox.p2.discovery_1.3.0.v20230322-1009.jar, Length: 57
# Word: (39.85kB), Length: 9
# Word: org.eclipse.e4.core.di.extensions.supplier_0.17.0.v20230429-1914.jar, Length: 68
# Word: (42.27kB), Length: 9
# Word: org.eclipse.jsch.core, Length: 21
# Word: org.eclipse.tm.terminal.view.core, Length: 33
# Word: org.eclipse.nebula.widgets.tablecombo_1.2.0.202305300939.jar, Length: 60
# Word: (41.98kB), Length: 9
# Word: org.eclipse.jsch.core_1.5.0.v20230317-0901.jar, Length: 46
# Word: (43.19kB), Length: 9
# Word: org.eclipse.m2e.apt.ui, Length: 22
# Word: 21:51:56], Length: 9
# Word: org.eclipse.m2e.profiles.ui_2.0.300.20230520-0934.jar, Length: 53
# Word: (42.7kB), Length: 8
# Word: org.eclipse.tm.terminal.view.core_4.9.100.202303140100.jar, Length: 58
# Word: (44.19kB), Length: 9
# Word: org.eclipse.m2e.apt.ui_2.0.400.20230520-0934.jar, Length: 48
# Word: (44.91kB), Length: 9
# Word: org.eclipse.compare.win32, Length: 25
# Word: org.eclipse.mylyn.commons.identity.core, Length: 39
# Word: org.eclipse.ui.net, Length: 18
# Word: org.eclipse.equinox.p2.transport.ecf, Length: 36
# Word: org.eclipse.core.externaltools_1.3.0.v20230317-0802.jar, Length: 55
# Word: javax.annotation, Length: 16
# Word: org.eclipse.equinox.p2.transport.ecf_1.4.0.v20230415-1327.jar, Length: 61
# Word: (47.97kB), Length: 9
# Word: (44.73kB), Length: 9
# Word: org.eclipse.compare.win32_1.3.0.v20230317-0901.jar, Length: 50
# Word: (46.18kB), Length: 9
# Word: org.eclipse.mylyn.commons.identity.core_3.26.1.v20230604-1755.jar, Length: 65
# Word: (47kB), Length: 6
# Word: org.eclipse.e4.ui.bindings, Length: 26
# Word: org.eclipse.ui.net_1.5.0.v20230317-0901.jar, Length: 43
# Word: (47.76kB), Length: 9
# Word: org.eclipse.core.net, Length: 20
# Word: 21:51:57], Length: 9
# Word: org.eclipse.mylyn.commons.repositories.core, Length: 43
# Word: org.eclipse.equinox.p2.reconciler.dropins, Length: 41
# Word: org.eclipse.equinox.p2.reconciler.dropins_1.5.0.v20230330-0930.jar, Length: 66
# Word: (51.45kB), Length: 9
# Word: javax.annotation_1.3.5.v20230504-0748.jar, Length: 41
# Word: (48.11kB), Length: 9
# Word: org.eclipse.e4.ui.bindings_0.14.0.v20230501-1823.jar, Length: 52
# Word: (48.17kB), Length: 9
# Word: org.eclipse.e4.emf.xpath, Length: 24
# Word: org.eclipse.core.net_1.5.0.v20230317-0901.jar, Length: 45
# Word: (49.44kB), Length: 9
# Word: org.eclipse.mylyn.monitor.ui, Length: 28
# Word: 21:51:58], Length: 9
# Word: org.eclipse.mylyn.commons.repositories.core_3.26.1.v20230604-1755.jar, Length: 69
# Word: (50.21kB), Length: 9
# Word: org.eclipse.urischeme, Length: 21
# Word: org.eclipse.e4.core.di, Length: 22
# Word: org.eclipse.e4.emf.xpath_0.4.0.v20230317-0802.jar, Length: 49
# Word: (52.84kB), Length: 9
# Word: org.eclipse.ecf.discovery, Length: 25
# Word: org.eclipse.e4.core.contexts, Length: 28
# Word: org.apache.commons.cli, Length: 22
# Word: org.eclipse.mylyn.monitor.ui_3.26.1.v20230604-1755.jar, Length: 54
# Word: (53.45kB), Length: 9
# Word: org.eclipse.urischeme_1.3.0.v20230317-0802.jar, Length: 46
# Word: (53.7kB), Length: 8
# Word: org.eclipse.e4.core.di_1.9.0.v20230429-1914.jar, Length: 47
# Word: (54.33kB), Length: 9
# Word: org.eclipse.e4.ui.dialogs, Length: 25
# Word: org.eclipse.oomph.predicates.edit, Length: 33
# Word: 21:51:59], Length: 9
# Word: org.eclipse.equinox.p2.discovery.compatibility, Length: 46
# Word: org.eclipse.ecf.discovery_5.1.2.v20230528-2254.jar, Length: 50
# Word: (55.95kB), Length: 9
# Word: org.eclipse.e4.core.contexts_1.12.0.v20230510-1240.jar, Length: 54
# Word: (56.42kB), Length: 9
# Word: org.apache.commons.cli_1.5.0.jar, Length: 32
# Word: (56.92kB), Length: 9
# Word: org.eclipse.oomph.predicates.edit_1.15.0.v20230416-0642.jar, Length: 59
# Word: (59.04kB), Length: 9
# Word: org.eclipse.equinox.p2.director.app, Length: 35
# Word: org.eclipse.equinox.p2.discovery.compatibility_1.3.0.v20230322-1009.jar, Length: 71
# Word: (60.43kB), Length: 9
# Word: org.eclipse.e4.ui.dialogs_1.4.0.v20230317-0802.jar, Length: 50
# Word: (58.53kB), Length: 9
# Word: org.eclipse.ui.monitoring, Length: 25
# Word: org.eclipse.tm.terminal.connector.ssh, Length: 37
# Word: org.eclipse.mylyn.commons.notifications.ui, Length: 42
# Word: org.eclipse.equinox.p2.jarprocessor, Length: 35
# Word: 21:52:00], Length: 9
# Word: org.eclipse.ui.monitoring_1.3.0.v20230317-0802.jar, Length: 50
# Word: (61.72kB), Length: 9
# Word: org.eclipse.m2e.apt.core, Length: 24
# Word: org.eclipse.equinox.p2.director.app_1.3.0.v20230330-0930.jar, Length: 60
# Word: (61.66kB), Length: 9
# Word: org.eclipse.mylyn.commons.notifications.ui_3.26.1.v20230604-1755.jar, Length: 68
# Word: (63.4kB), Length: 8
# Word: junit-vintage-engine, Length: 20
# Word: org.eclipse.tm.terminal.connector.ssh_4.8.100.202303140100.jar, Length: 62
# Word: (62.03kB), Length: 9
# Word: junit-vintage-engine_5.9.3.jar, Length: 30
# Word: (65.33kB), Length: 9
# Word: (66.11kB), Length: 9
# Word: org.eclipse.ecf.identity, Length: 24
# Word: org.eclipse.m2e.apt.core_2.2.100.20230520-0934.jar, Length: 50
# Word: (65.27kB), Length: 9
# Word: org.eclipse.equinox.p2.jarprocessor_1.3.0.v20230330-1254.jar, Length: 60
# Word: (63.57kB), Length: 9
# Word: org.eclipse.ecf.identity_3.10.0.v20230422-0242.jar, Length: 50
# Word: (67.72kB), Length: 9
# Word: org.eclipse.compare.core, Length: 24
# Word: org.eclipse.tips.ui, Length: 19
# Word: 21:52:01], Length: 9
# Word: org.eclipse.cdt.core.native, Length: 27
# Word: org.eclipse.mylyn.resources.ui, Length: 30
# Word: org.eclipse.mylyn.tasks.search, Length: 30
# Word: org.eclipse.equinox.frameworkadmin.equinox, Length: 42
# Word: org.eclipse.mylyn.resources.ui_3.26.1.v20230604-1755.jar, Length: 56
# Word: (70.34kB), Length: 9
# Word: org.eclipse.e4.core.services, Length: 28
# Word: org.eclipse.mylyn.tasks.search_3.26.1.v20230604-1755.jar, Length: 56
# Word: (70.8kB), Length: 8
# Word: org.eclipse.core.filesystem, Length: 27
# Word: org.eclipse.jdt.apt.ui, Length: 22
# Word: org.eclipse.core.runtime, Length: 24
# Word: org.eclipse.compare.core_3.8.0.v20230517-1315.jar, Length: 49
# Word: (69.26kB), Length: 9
# Word: org.eclipse.mylyn.github.core, Length: 29
# Word: org.eclipse.cdt.core.native_6.3.200.202303140100.jar, Length: 52
# Word: (70.09kB), Length: 9
# Word: org.eclipse.tips.ui_0.3.0.v20230317-0802.jar, Length: 44
# Word: (69.32kB), Length: 9
# Word: org.eclipse.core.filesystem_1.10.0.v20230425-0513.jar, Length: 53
# Word: (71.88kB), Length: 9
# Word: org.eclipse.equinox.p2.operations, Length: 33
# Word: org.eclipse.jdt.apt.ui_3.8.0.v20230323-1537.jar, Length: 47
# Word: (73.78kB), Length: 9
# Word: 21:52:02], Length: 9
# Word: org.eclipse.equinox.frameworkadmin.equinox_1.2.300.v20230320-0659.jar, Length: 69
# Word: (70.94kB), Length: 9
# Word: org.eclipse.equinox.p2.operations_2.7.0.v20230322-1009.jar, Length: 58
# Word: (77.31kB), Length: 9
# Word: org.eclipse.core.runtime_3.27.0.v20230515-1719.jar, Length: 50
# Word: (74.42kB), Length: 9
# Word: org.eclipse.e4.core.services_2.4.0.v20230429-1914.jar, Length: 53
# Word: (71.48kB), Length: 9
# Word: org.eclipse.equinox.p2.core, Length: 27
# Word: org.eclipse.mylyn.github.core_6.2.1.v20230531-0547.jar, Length: 54
# Word: (76.45kB), Length: 9
# Word: org.eclipse.equinox.p2.ui.sdk, Length: 29
# Word: 21:52:03], Length: 9
# Word: com.ibm.icu, Length: 11
# Word: org.eclipse.equinox.p2.core_2.10.0.v20230330-0930.jar, Length: 53
# Word: (79.47kB), Length: 9
# Word: org.eclipse.jdt.ui, Length: 18
# Word: org.eclipse.wildwebdeveloper.xml, Length: 32
# Word: org.eclipse.jdt.doc.user, Length: 24
# Word: org.eclipse.equinox.p2.ui.sdk_1.3.0.v20230507-1427.jar, Length: 54
# Word: (80.71kB), Length: 9
# Word: org.eclipse.m2e.maven.runtime, Length: 29
# Word: com.ibm.icu_73.1.0.jar, Length: 22
# Word: (13.89MB), Length: 9
# Word: org.eclipse.egit.doc, Length: 20
# Word: org.eclipse.jdt.ui_3.29.0.v20230525-0728.jar, Length: 44
# Word: (10.97MB), Length: 9
# Word: org.eclipse.platform.doc.user, Length: 29
# Word: 21:52:04], Length: 9
# Word: org.eclipse.m2e.maven.runtime_3.9.100.20230519-1558.jar, Length: 55
# Word: (7.65MB), Length: 8
# Word: org.eclipse.jdt.core, Length: 20
# Word: org.eclipse.egit.ui, Length: 19
# Word: org.eclipse.platform.doc.user_4.28.0.v20230601-1614.jar, Length: 55
# Word: (4.21MB), Length: 8
# Word: 21:52:05], Length: 9
# Word: org.apache.lucene.core, Length: 22
# Word: org.eclipse.wildwebdeveloper.xml_1.1.0.202304242122.jar, Length: 55
# Word: (8.82MB), Length: 8
# Word: org.eclipse.jdt.doc.user_3.15.1800.v20230601-1614.jar, Length: 53
# Word: (7.77MB), Length: 8
# Word: org.eclipse.jdt.core_3.34.0.v20230512-1803.jar, Length: 46
# Word: (4.01MB), Length: 8
# Word: 21:52:06], Length: 9
# Word: org.eclipse.egit.ui_6.6.0.202305301015-r.jar, Length: 44
# Word: (3.9MB), Length: 7
# Word: org.apache.lucene.core_9.5.0.v20230521-0510.jar, Length: 47
# Word: (3.77MB), Length: 8
# Word: 21:52:07], Length: 9
# Word: org.eclipse.egit.doc_6.6.0.202305301015-r.jar, Length: 45
# Word: (4.45MB), Length: 8
# Word: 21:52:08], Length: 9
# Word: 21:52:11], Length: 9
# Word: 21:52:12], Length: 9
# Word: org.eclipse.ui.workbench, Length: 24
# Word: 21:52:13], Length: 9
# Word: org.eclipse.jdt.core.compiler.batch, Length: 35
# Word: org.eclipse.ui.workbench_3.129.0.v20230525-0648.jar, Length: 51
# Word: (3.5MB), Length: 7
# Word: org.eclipse.debug.ui, Length: 20
# Word: 21:52:14], Length: 9
# Word: org.eclipse.jdt.core.compiler.batch_3.34.0.v20230523-1233.jar, Length: 61
# Word: (3.03MB), Length: 8
# Word: org.eclipse.debug.ui_3.18.0.v20230516-0719.jar, Length: 46
# Word: 21:52:15], Length: 9
# Word: (2.96MB), Length: 8
# Word: 21:52:16], Length: 9
# Word: 21:52:18], Length: 9
# Word: org.gradle.toolingapi, Length: 21
# Word: org.eclipse.swt.win32.win32.x86_64, Length: 34
# Word: org.eclipse.jdt.core.manipulation, Length: 33
# Word: org.eclipse.ui.ide, Length: 18
# Word: 21:52:19], Length: 9
# Word: org.gradle.toolingapi_8.1.1.v20230428-1350.jar, Length: 46
# Word: (2.7MB), Length: 7
# Word: org.eclipse.ui.intro.universal, Length: 30
# Word: org.eclipse.jdt.core.manipulation_1.19.0.v20230512-1848.jar, Length: 59
# Word: (2.45MB), Length: 8
# Word: org.eclipse.mylyn.tasks.ui, Length: 26
# Word: org.eclipse.swt.win32.win32.x86_64_3.124.0.v20230523-1044.jar, Length: 61
# Word: (2.48MB), Length: 8
# Word: org.eclipse.ui.ide_3.21.0.v20230526-1500.jar, Length: 44
# Word: (2.32MB), Length: 8
# Word: 21:52:20], Length: 9
# Word: org.eclipse.mylyn.tasks.ui_3.26.1.v20230604-1755.jar, Length: 52
# Word: (1.98MB), Length: 8
# Word: org.eclipse.ui.intro.universal_3.5.0.v20230317-0802.jar, Length: 55
# Word: (2.1MB), Length: 7
# Word: 21:52:21], Length: 9
# Word: 21:52:22], Length: 9
# Word: org.apache.lucene.analysis-common, Length: 33
# Word: 21:52:23], Length: 9
# Word: org.eclipse.jdt.debug.ui, Length: 24
# Word: org.apache.lucene.analysis-common_9.5.0.v20230521-0510.jar, Length: 58
# Word: (1.89MB), Length: 8
# Word: org.jcodings, Length: 12
# Word: org.eclipse.osgi, Length: 16
# Word: 21:52:24], Length: 9
# Word: org.eclipse.jdt.debug.ui_3.13.0.v20230421-0438.jar, Length: 50
# Word: (1.67MB), Length: 8
# Word: org.jcodings_1.0.58.jar, Length: 23
# Word: (1.66MB), Length: 8
# Word: org.eclipse.osgi_3.18.400.v20230509-2241.jar, Length: 44
# Word: (1.47MB), Length: 8
# Word: 21:52:25], Length: 9
# Word: org.eclipse.team.ui, Length: 19
# Word: 21:52:26], Length: 9
# Word: org.eclipse.mylyn.help.ui, Length: 25
# Word: com.sun.xml.bind, Length: 16
# Word: org.eclipse.team.ui_3.10.0.v20230317-0901.jar, Length: 45
# Word: (1.42MB), Length: 8
# Word: 21:52:27], Length: 9
# Word: com.sun.xml.bind_2.3.3.v20221203-1659.jar, Length: 41
# Word: (1.16MB), Length: 8
# Word: org.eclipse.mylyn.help.ui_3.26.1.v20230604-1755.jar, Length: 51
# Word: (1.22MB), Length: 8
# Word: org.eclipse.jface, Length: 17
# Word: 21:52:28], Length: 9
# Word: org.eclipse.ant.ui, Length: 18
# Word: org.eclipse.jface_3.30.0.v20230509-0720.jar, Length: 43
# Word: (1.12MB), Length: 8
# Word: 21:52:29], Length: 9
# Word: org.eclipse.ant.ui_3.9.0.v20230329-1001.jar, Length: 43
# Word: (1.04MB), Length: 8
# Word: org.eclipse.jface.text, Length: 22
# Word: org.eclipse.jdt.debug, Length: 21
# Word: 21:52:30], Length: 9
# Word: org.eclipse.jface.text_3.24.0.v20230525-0719.jar, Length: 48
# Word: org.eclipse.core.resources, Length: 26
# Word: org.eclipse.jdt.debug_3.21.0.v20230329-1610.jar, Length: 47
# Word: (918.71kB), Length: 10
# Word: 21:52:31], Length: 9
# Word: org.eclipse.wst.xml.core, Length: 24
# Word: org.eclipse.m2e.core.ui, Length: 23
# Word: org.eclipse.core.resources_3.19.0.v20230510-1240.jar, Length: 52
# Word: (892.87kB), Length: 10
# Word: 21:52:32], Length: 9
# Word: org.eclipse.wst.xml.core_1.2.700.v202305221615.jar, Length: 50
# Word: (811.52kB), Length: 10
# Word: org.eclipse.compare, Length: 19
# Word: org.eclipse.help.webapp, Length: 23
# Word: org.eclipse.m2e.core.ui_2.0.5.20230320-1220.jar, Length: 47
# Word: (810.77kB), Length: 10
# Word: org.eclipse.compare_3.9.0.v20230504-0624.jar, Length: 44
# Word: (808kB), Length: 7
# Word: 21:52:33], Length: 9
# Word: org.eclipse.help.webapp_3.11.0.v20230503-0629.jar, Length: 49
# Word: (739.18kB), Length: 10
# Word: org.eclipse.equinox.p2.ui, Length: 25
# Word: 21:52:34], Length: 9
# Word: org.eclipse.ui.workbench.texteditor, Length: 35
# Word: org.eclipse.buildship.ui, Length: 24
# Word: org.eclipse.equinox.p2.ui_2.8.0.v20230510-1208.jar, Length: 50
# Word: (697.75kB), Length: 10
# Word: org.eclipse.cdt.core.win32.x86_64, Length: 33
# Word: 21:52:35], Length: 9
# Word: org.eclipse.buildship.ui_3.1.7.v20230428-1350.jar, Length: 49
# Word: (675.98kB), Length: 10
# Word: org.eclipse.ui.workbench.texteditor_3.17.0.v20230316-1200.jar, Length: 61
# Word: (691.1kB), Length: 9
# Word: org.eclipse.m2e.core, Length: 20
# Word: 21:52:36], Length: 9
# Word: org.eclipse.cdt.core.win32.x86_64_11.2.0.202306051917.jar, Length: 57
# Word: (648.32kB), Length: 10
# Word: org.eclipse.egit.core, Length: 21
# Word: org.eclipse.m2e.core_2.0.8.20230520-0934.jar, Length: 44
# Word: (640.8kB), Length: 9
# Word: org.eclipse.ui.editors, Length: 22
# Word: 21:52:37], Length: 9
# Word: org.eclipse.jdt.launching, Length: 25
# Word: org.eclipse.egit.core_6.6.0.202305301015-r.jar, Length: 46
# Word: (628.45kB), Length: 10
# Word: org.eclipse.ui.editors_3.16.0.v20230329-1609.jar, Length: 48
# Word: (611.57kB), Length: 10
# Word: junit-jupiter-params, Length: 20
# Word: 21:52:38], Length: 9
# Word: (586.4kB), Length: 9
# Word: junit-jupiter-params_5.9.3.jar, Length: 30
# Word: (566.02kB), Length: 10
# Word: org.eclipse.jdt.junit, Length: 21
# Word: org.eclipse.buildship.core, Length: 26
# Word: org.eclipse.jdt.launching_3.20.0.v20230425-1118.jar, Length: 51
# Word: (571.95kB), Length: 10
# Word: 21:52:39], Length: 9
# Word: org.eclipse.help.ui, Length: 19
# Word: org.apache.lucene.queries, Length: 25
# Word: org.eclipse.search, Length: 18
# Word: org.eclipse.buildship.core_3.1.7.v20230428-1350.jar, Length: 51
# Word: (537.54kB), Length: 10
# Word: org.apache.lucene.queries_9.5.0.v20230521-0510.jar, Length: 50
# Word: (529.66kB), Length: 10
# Word: org.eclipse.search_3.15.0.v20230427-2049.jar, Length: 44
# Word: (499.82kB), Length: 10
# Word: 21:52:40], Length: 9
# Word: org.eclipse.jdt.junit_3.16.0.v20230420-0409.jar, Length: 47
# Word: (547.35kB), Length: 10
# Word: org.eclipse.mylyn.tasks.core, Length: 28
# Word: org.eclipse.help.ui_4.5.0.v20230317-0802.jar, Length: 44
# Word: (536.91kB), Length: 10
# Word: org.eclipse.wst.sse.core, Length: 24
# Word: org.eclipse.mylyn.tasks.core_3.26.1.v20230604-1755.jar, Length: 54
# Word: (491.21kB), Length: 10
# Word: 21:52:41], Length: 9
# Word: org.eclipse.ltk.ui.refactoring, Length: 30
# Word: org.eclipse.ltk.ui.refactoring_3.13.0.v20230325-0319.jar, Length: 56
# Word: (470.77kB), Length: 10
# Word: org.apache.lucene.queryparser, Length: 29
# Word: org.eclipse.wst.sse.core_1.2.1100.v202305221405.jar, Length: 51
# Word: (479.84kB), Length: 10
# Word: org.eclipse.help.base, Length: 21
# Word: 21:52:42], Length: 9
# Word: org.apache.lucene.queryparser_9.5.0.v20230521-0510.jar, Length: 54
# Word: (448.96kB), Length: 10
# Word: org.eclipse.ui, Length: 14
# Word: org.eclipse.help.base_4.4.0.v20230605-0440.jar, Length: 46
# Word: (434.5kB), Length: 9
# Word: org.eclipse.ui.navigator, Length: 24
# Word: 21:52:43], Length: 9
# Word: org.eclipse.m2e.model.edit, Length: 26
# Word: org.eclipse.team.core, Length: 21
# Word: org.eclipse.ui_3.203.100.v20230417-1307.jar, Length: 43
# Word: (434.06kB), Length: 10
# Word: org.eclipse.debug.core, Length: 22
# Word: org.eclipse.ui.navigator_3.12.0.v20230329-1313.jar, Length: 50
# Word: (425.54kB), Length: 10
# Word: org.eclipse.e4.ui.model.workbench, Length: 33
# Word: org.eclipse.m2e.model.edit_2.0.300.20230320-2130.jar, Length: 52
# Word: (410.69kB), Length: 10
# Word: org.eclipse.debug.core_3.21.0.v20230508-1538.jar, Length: 48
# Word: (400.4kB), Length: 9
# Word: 21:52:44], Length: 9
# Word: org.eclipse.team.core_3.10.0.v20230317-0901.jar, Length: 47
# Word: (402.82kB), Length: 10
# Word: org.eclipse.e4.ui.model.workbench_2.4.0.v20230404-0801.jar, Length: 58
# Word: (395.49kB), Length: 10
# Word: org.eclipse.jdt.apt.core, Length: 24
# Word: org.eclipse.ui.cheatsheets, Length: 26
# Word: org.eclipse.equinox.p2.metadata, Length: 31
# Word: org.eclipse.mylyn.builds.ui, Length: 27
# Word: org.eclipse.jdt.apt.core_3.8.0.v20230413-1556.jar, Length: 49
# Word: (393.84kB), Length: 10
# Word: org.eclipse.mylyn.builds.ui_3.26.1.v20230604-1755.jar, Length: 53
# Word: (349.65kB), Length: 10
# Word: 21:52:45], Length: 9
# Word: org.eclipse.ui.cheatsheets_3.8.0.v20230317-0802.jar, Length: 51
# Word: (387.35kB), Length: 10
# Word: org.eclipse.equinox.p2.metadata_2.7.0.v20230403-0851.jar, Length: 56
# Word: (362.53kB), Length: 10
# Word: org.eclipse.ui.intro, Length: 20
# Word: org.eclipse.ltk.core.refactoring, Length: 32
# Word: 21:52:46], Length: 9
# Word: javax.xml, Length: 9
# Word: org.eclipse.ui.forms, Length: 20
# Word: org.eclipse.mylyn.commons.ui, Length: 28
# Word: org.eclipse.tips.ide, Length: 20
# Word: org.eclipse.ui.forms_3.12.0.v20230317-0802.jar, Length: 46
# Word: (331.6kB), Length: 9
# Word: org.eclipse.mylyn.reviews.ui, Length: 28
# Word: org.eclipse.mylyn.commons.ui_3.26.1.v20230604-1755.jar, Length: 54
# Word: (331.05kB), Length: 10
# Word: org.apache.commons.httpclient, Length: 29
# Word: 21:52:47], Length: 9
# Word: org.eclipse.ui.intro_3.7.0.v20230503-0628.jar, Length: 45
# Word: (346.48kB), Length: 10
# Word: org.eclipse.tips.ide_0.3.0.v20230429-1617.jar, Length: 45
# Word: (330.09kB), Length: 10
# Word: org.eclipse.ltk.core.refactoring_3.14.0.v20230323-1830.jar, Length: 58
# Word: (343.2kB), Length: 9
# Word: org.eclipse.mylyn.reviews.ui_3.26.1.v20230604-1755.jar, Length: 54
# Word: (318.22kB), Length: 10
# Word: javax.xml_1.4.1.v20220503-2331.jar, Length: 34
# Word: (339.43kB), Length: 10
# Word: org.eclipse.core.databinding.observable, Length: 39
# Word: org.apache.commons.httpclient_3.1.0.v201012070820.jar, Length: 53
# Word: (314.74kB), Length: 10
# Word: org.eclipse.eclemma.ui, Length: 22
# Word: 21:52:48], Length: 9
# Word: org.apache.commons.lang, Length: 23
# Word: org.eclipse.text, Length: 16
# Word: org.eclipse.core.databinding.observable_1.13.0.v20230501-1533.jar, Length: 65
# Word: (314.71kB), Length: 10
# Word: org.eclipse.eclemma.ui_3.1.7.202306070845.jar, Length: 45
# Word: (309.6kB), Length: 9
# Word: org.apache.commons.lang_2.6.0.v20220406-2305.jar, Length: 48
# Word: (300.96kB), Length: 10
# Word: org.eclipse.jface.databinding, Length: 29
# Word: org.eclipse.core.databinding, Length: 28
# Word: org.eclipse.text_3.13.0.v20230316-1200.jar, Length: 42
# Word: (297.21kB), Length: 10
# Word: 21:52:49], Length: 9
# Word: org.eclipse.tm.terminal.view.ui, Length: 31
# Word: org.eclipse.tm4e.core, Length: 21
# Word: org.eclipse.e4.ui.workbench, Length: 27
# Word: org.jacoco.agent, Length: 16
# Word: org.eclipse.jface.databinding_1.15.0.v20230317-0802.jar, Length: 55
# Word: (291.45kB), Length: 10
# Word: org.eclipse.core.databinding_1.13.0.v20230501-1533.jar, Length: 54
# Word: (286.11kB), Length: 10
# Word: org.eclipse.equinox.p2.repository.tools, Length: 39
# Word: org.eclipse.tm4e.core_0.5.4.202305171341.jar, Length: 44
# Word: (268.38kB), Length: 10
# Word: org.eclipse.tm.terminal.view.ui_4.11.100.202304132101.jar, Length: 57
# Word: (279.6kB), Length: 9
# Word: org.eclipse.e4.ui.workbench_1.15.0.v20230501-1823.jar, Length: 53
# Word: (266.83kB), Length: 10
# Word: 21:52:50], Length: 9
# Word: org.eclipse.help_3.10.0.v20230317-0802.jar, Length: 42
# Word: (272.02kB), Length: 10
# Word: org.eclipse.equinox.p2.repository.tools_2.4.0.v20230330-1254.jar, Length: 64
# Word: (256.22kB), Length: 10
# Word: org.eclipse.mylyn.github.ui, Length: 27
# Word: org.eclipse.e4.ui.workbench.renderers.swt, Length: 41
# Word: org.jacoco.agent_0.8.10.202304240956.jar, Length: 40
# Word: (265.7kB), Length: 9
# Word: 21:52:51], Length: 9
# Word: org.eclipse.mylyn.github.ui_6.2.1.v20230531-0547.jar, Length: 52
# Word: (256.06kB), Length: 10
# Word: org.eclipse.e4.ui.workbench.renderers.swt_0.16.0.v20230525-0648.jar, Length: 67
# Word: (255.6kB), Length: 9
# Word: org.apache.lucene.sandbox, Length: 25
# Word: org.eclipse.egit.github.core, Length: 28
# Word: org.eclipse.equinox.p2.publisher.eclipse, Length: 40
# Word: org.eclipse.ui.console, Length: 22
# Word: org.apache.lucene.sandbox_9.5.0.v20230521-0510.jar, Length: 50
# Word: (253.87kB), Length: 10
# Word: 21:52:52], Length: 9
# Word: junit-jupiter-engine, Length: 20
# Word: org.eclipse.mylyn.github.doc, Length: 28
# Word: org.eclipse.equinox.p2.engine, Length: 29
# Word: org.eclipse.egit.github.core_6.1.0.202203080745-r.jar, Length: 53
# Word: (248.87kB), Length: 10
# Word: org.eclipse.eclemma.doc, Length: 23
# Word: org.eclipse.ui.console_3.12.0.v20230317-0802.jar, Length: 48
# Word: (245.2kB), Length: 9
# Word: org.eclipse.e4.ui.css.core, Length: 26
# Word: org.joni, Length: 8
# Word: org.eclipse.equinox.p2.engine_2.8.0.v20230509-0902.jar, Length: 54
# Word: (234.43kB), Length: 10
# Word: 21:52:53], Length: 9
# Word: org.eclipse.tm.terminal.control, Length: 31
# Word: org.eclipse.mylyn.builds.core, Length: 29
# Word: org.eclipse.equinox.p2.publisher.eclipse_1.5.0.v20230330-1254.jar, Length: 65
# Word: (246.1kB), Length: 9
# Word: org.joni_2.1.48.jar, Length: 19
# Word: (214.2kB), Length: 9
# Word: junit-jupiter-engine_5.9.3.jar, Length: 30
# Word: (240.88kB), Length: 10
# Word: org.eclipse.e4.ui.css.core_0.14.0.v20230317-0802.jar, Length: 52
# Word: (215.88kB), Length: 10
# Word: org.eclipse.mylyn.github.doc_6.2.1.v20230523-1926.jar, Length: 53
# Word: (235.21kB), Length: 10
# Word: org.eclipse.tm.terminal.control_5.4.100.202303140100.jar, Length: 56
# Word: (213.28kB), Length: 10
# Word: org.eclipse.eclemma.doc_3.1.7.202306070845.jar, Length: 46
# Word: (225.84kB), Length: 10
# Word: 21:52:54], Length: 9
# Word: org.eclipse.mylyn.builds.core_3.26.1.v20230604-1755.jar, Length: 55
# Word: (212.79kB), Length: 10
# Word: org.eclipse.e4.ui.progress, Length: 26
# Word: org.eclipse.ui.browser, Length: 22
# Word: org.eclipse.e4.ui.css.swt, Length: 25
# Word: junit-jupiter-api, Length: 17
# Word: org.jacoco.core, Length: 15
# Word: org.eclipse.tm4e.ui, Length: 19
# Word: (210.82kB), Length: 10
# Word: org.eclipse.e4.ui.progress_0.4.0.v20230501-1823.jar, Length: 51
# Word: (209.52kB), Length: 10
# Word: org.eclipse.ui.browser_3.8.0.v20230329-1440.jar, Length: 47
# Word: (209.24kB), Length: 10
# Word: junit-jupiter-api_5.9.3.jar, Length: 27
# Word: (202.89kB), Length: 10
# Word: 21:52:55], Length: 9
# Word: junit-platform-engine, Length: 21
# Word: org.eclipse.e4.ui.css.swt_0.15.0.v20230317-0802.jar, Length: 51
# Word: (205.08kB), Length: 10
# Word: org.eclipse.equinox.p2.repository, Length: 33
# Word: org.jacoco.core_0.8.10.202304240956.jar, Length: 39
# Word: (199.56kB), Length: 10
# Word: org.eclipse.jdt.junit.core, Length: 26
# Word: org.eclipse.mylyn.commons.workbench, Length: 35
# Word: org.eclipse.ui.navigator.resources, Length: 34
# Word: org.eclipse.tm4e.ui_0.6.4.202305161247.jar, Length: 42
# Word: (189.31kB), Length: 10
# Word: 21:52:56], Length: 9
# Word: junit-platform-engine_1.9.3.jar, Length: 31
# Word: (184.79kB), Length: 10
# Word: org.eclipse.equinox.p2.repository_2.7.0.v20230507-1427.jar, Length: 58
# Word: (182.41kB), Length: 10
# Word: org.eclipse.mylyn.commons.workbench_3.26.1.v20230604-1755.jar, Length: 61
# Word: (178.66kB), Length: 10
# Word: org.eclipse.jdt.junit.core_3.12.0.v20230323-1830.jar, Length: 52
# Word: (178.78kB), Length: 10
# ...
# Word: org.eclipse.m2e.lemminx.feature.feature.jar, Length: 43
# Word: [2.1.200.20230523-2106], Length: 23
# Word: org.eclipse.m2e.logback.feature.feature.group, Length: 45
# Word: [2.1.2.20230523-2106], Length: 21
# Word: org.eclipse.m2e.logback.feature.feature.jar, Length: 43
# Word: [3.9.100.20230519-1558], Length: 23
# Word: [2.0.300.20230320-2130], Length: 23
# Word: [2.0.300.20230520-0934], Length: 23
# Word: org.eclipse.m2e.refactoring, Length: 27
# Word: [2.0.300.20221210-1303], Length: 23
# Word: org.eclipse.m2e.scm, Length: 19
# Word: [2.0.200.20230207-0948], Length: 23
# Word: org.eclipse.m2e.workspace.cli, Length: 29
# Word: [0.3.1], Length: 7
# Word: [3.26.1.v20230604-1755], Length: 23
# Word: org.eclipse.mylyn.builds.feature.group, Length: 38
# Word: org.eclipse.mylyn.builds.feature.jar, Length: 36
# Word: org.eclipse.mylyn.commons.activity.feature.group, Length: 48
# Word: org.eclipse.mylyn.commons.activity.feature.jar, Length: 46
# Word: org.eclipse.mylyn.commons.feature.group, Length: 39
# Word: org.eclipse.mylyn.commons.feature.jar, Length: 37
# Word: org.eclipse.mylyn.commons.identity.feature.group, Length: 48
# Word: org.eclipse.mylyn.commons.identity.feature.jar, Length: 46
# Word: org.eclipse.mylyn.commons.notifications.feature.group, Length: 53
# Word: org.eclipse.mylyn.commons.notifications.feature.jar, Length: 51
# Word: org.eclipse.mylyn.commons.repositories.feature.group, Length: 52
# Word: org.eclipse.mylyn.commons.repositories.feature.jar, Length: 50
# Word: org.eclipse.mylyn.commons.repositories.http.feature.group, Length: 57
# Word: org.eclipse.mylyn.commons.repositories.http.feature.jar, Length: 55
# Word: org.eclipse.mylyn.context_feature.feature.group, Length: 47
# Word: org.eclipse.mylyn.context_feature.feature.jar, Length: 45
# Word: org.eclipse.mylyn.discovery.feature.group, Length: 41
# Word: org.eclipse.mylyn.discovery.feature.jar, Length: 39
# Word: org.eclipse.mylyn.egit.feature.feature.group, Length: 44
# Word: [3.26.1.v20230531-0547], Length: 23
# Word: org.eclipse.mylyn.egit.feature.feature.jar, Length: 42
# Word: org.eclipse.mylyn.git.feature.group, Length: 35
# Word: org.eclipse.mylyn.git.feature.jar, Length: 33
# Word: [6.2.1.v20230531-0547], Length: 22
# Word: [6.2.1.v20230523-1926], Length: 22
# Word: org.eclipse.mylyn.github.feature.feature.group, Length: 46
# Word: org.eclipse.mylyn.github.feature.feature.jar, Length: 44
# Word: org.eclipse.mylyn.hudson.feature.group, Length: 38
# Word: org.eclipse.mylyn.hudson.feature.jar, Length: 36
# Word: org.eclipse.mylyn.ide_feature.feature.group, Length: 43
# Word: org.eclipse.mylyn.ide_feature.feature.jar, Length: 41
# Word: org.eclipse.mylyn.java_feature.feature.group, Length: 44
# Word: org.eclipse.mylyn.java_feature.feature.jar, Length: 42
# Word: org.eclipse.mylyn.monitor.feature.group, Length: 39
# Word: org.eclipse.mylyn.monitor.feature.jar, Length: 37
# Word: org.eclipse.mylyn.reviews.feature.feature.group, Length: 47
# Word: org.eclipse.mylyn.reviews.feature.feature.jar, Length: 45
# Word: org.eclipse.mylyn.tasks.ide.feature.group, Length: 41
# Word: org.eclipse.mylyn.tasks.ide.feature.jar, Length: 39
# Word: org.eclipse.mylyn.team_feature.feature.group, Length: 44
# Word: org.eclipse.mylyn.team_feature.feature.jar, Length: 42
# Word: org.eclipse.mylyn.versions.feature.group, Length: 40
# Word: org.eclipse.mylyn.versions.feature.jar, Length: 38
# Word: org.eclipse.mylyn.wikitext, Length: 26
# Word: [3.0.46.202301111837], Length: 21
# Word: org.eclipse.mylyn.wikitext.ant, Length: 30
# Word: org.eclipse.mylyn.wikitext.asciidoc, Length: 35
# Word: org.eclipse.mylyn.wikitext.asciidoc.ui, Length: 38
# Word: org.eclipse.mylyn.wikitext.confluence, Length: 37
# Word: org.eclipse.mylyn.wikitext.confluence.ui, Length: 40
# Word: org.eclipse.mylyn.wikitext.editors_feature.feature.group, Length: 56
# Word: org.eclipse.mylyn.wikitext.editors_feature.feature.jar, Length: 54
# Word: org.eclipse.mylyn.wikitext.help.ui, Length: 34
# Word: org.eclipse.mylyn.wikitext.html, Length: 31
# Word: org.eclipse.mylyn.wikitext.markdown, Length: 35
# Word: org.eclipse.mylyn.wikitext.markdown.ui, Length: 38
# Word: org.eclipse.mylyn.wikitext.mediawiki, Length: 36
# Word: org.eclipse.mylyn.wikitext.mediawiki.ui, Length: 39
# Word: org.eclipse.mylyn.wikitext.osgi, Length: 31
# Word: org.eclipse.mylyn.wikitext.textile, Length: 34
# Word: org.eclipse.mylyn.wikitext.textile.ui, Length: 37
# Word: org.eclipse.mylyn.wikitext.tracwiki, Length: 35
# Word: org.eclipse.mylyn.wikitext.tracwiki.ui, Length: 38
# Word: org.eclipse.mylyn.wikitext.twiki, Length: 32
# Word: org.eclipse.mylyn.wikitext.twiki.ui, Length: 35
# Word: org.eclipse.mylyn.wikitext.ui, Length: 29
# Word: org.eclipse.mylyn.wikitext_feature.feature.group, Length: 48
# Word: org.eclipse.mylyn.wikitext_feature.feature.jar, Length: 46
# Word: org.eclipse.mylyn_feature.feature.group, Length: 39
# Word: org.eclipse.mylyn_feature.feature.jar, Length: 37
# Word: org.eclipse.nebula.cwt, Length: 22
# Word: [1.0.0.201703081533], Length: 20
# Word: org.eclipse.nebula.widgets.cdatetime, Length: 36
# Word: [1.5.0.202303072132], Length: 20
# Word: [1.2.0.202305300939], Length: 20
# Word: [1.18.0.v20230617-1322], Length: 23
# Word: [1.17.0.v20230617-1322], Length: 23
# Word: org.eclipse.oomph.extractor.lib, Length: 31
# Word: [1.9.0.v20220421-1218], Length: 22
# Word: [1.18.0.v20230817-0718], Length: 23
# Word: org.eclipse.oomph.jreinfo.ui, Length: 28
# Word: [1.15.0.v20220520-1242], Length: 23
# Word: org.eclipse.oomph.jreinfo.win32.x86_64, Length: 38
# Word: [1.8.0.v20220421-1218], Length: 22
# Word: [1.26.0.v20230617-1322], Length: 23
# Word: [1.14.0.v20230625-0755], Length: 23
# Word: org.eclipse.oomph.p2.edit, Length: 25
# Word: [1.17.0.v20230204-0932], Length: 23
# Word: org.eclipse.oomph.p2.feature.group, Length: 34
# Word: [1.27.0.v20230828-1517], Length: 23
# Word: org.eclipse.oomph.p2.feature.jar, Length: 32
# Word: [1.21.0.v20230828-1517], Length: 23
# Word: [1.15.0.v20230416-0642], Length: 23
# Word: [1.14.0.v20230617-1322], Length: 23
# Word: org.eclipse.oomph.resources.edit, Length: 32
# Word: [1.13.0.v20230204-0932], Length: 23
# Word: [1.27.0.v20230714-1137], Length: 23
# Word: [1.28.0.v20230618-0610], Length: 23
# Word: org.eclipse.oomph.setup.core.feature.group, Length: 42
# Word: [1.28.0.v20230817-0718], Length: 23
# Word: org.eclipse.oomph.setup.core.feature.jar, Length: 40
# Word: [1.14.0.v20230618-0610], Length: 23
# Word: org.eclipse.oomph.setup.edit, Length: 28
# Word: [1.16.0.v20220421-1218], Length: 23
# Word: [1.26.0.v20230828-1517], Length: 23
# Word: org.eclipse.oomph.setup.feature.group, Length: 37
# Word: [1.29.0.v20230828-1517], Length: 23
# Word: org.eclipse.oomph.setup.feature.jar, Length: 35
# Word: [1.20.0.v20230617-1322], Length: 23
# Word: [1.16.0.v20230617-1322], Length: 23
# Word: org.eclipse.oomph.setup.sync, Length: 28
# Word: [1.14.0.v20220421-1218], Length: 23
# Word: org.eclipse.oomph.setup.ui.questionnaire, Length: 40
# Word: [1.13.0.v20220421-1218], Length: 23
# Word: [1.20.0.v20230828-1517], Length: 23
# Word: [1.20.0.v20230620-1408], Length: 23
# Word: org.eclipse.oomph.workingsets.edit, Length: 34
# Word: [1.15.0.v20230828-1517], Length: 23
# Word: [3.18.400.v20230509-2241], Length: 25
# Word: org.eclipse.osgi.compatibility.state, Length: 36
# Word: [1.2.800.v20221116-1440], Length: 24
# Word: org.eclipse.osgi.services, Length: 25
# Word: [3.11.100.v20221006-1531], Length: 25
# Word: org.eclipse.osgi.util, Length: 21
# Word: [3.7.200.v20230103-1101], Length: 24
# Word: [4.28.0.v20230605-0440], Length: 23
# Word: [4.28.0.v20230601-1614], Length: 23
# Word: org.eclipse.platform.feature.group, Length: 34
# Word: org.eclipse.platform.feature.jar, Length: 32
# Word: org.eclipse.rcp.feature.group, Length: 29
# Word: org.eclipse.rcp.feature.jar, Length: 27
# Word: [3.15.0.v20230427-2049], Length: 23
# Word: [3.124.0.v20230523-1044], Length: 24
# Word: [3.10.0.v20230317-0901], Length: 23
# Word: [3.13.0.v20230316-1200], Length: 23
# Word: [1.2.100.v20230427-1010], Length: 24
# Word: [0.3.0.v20230317-0802], Length: 22
# Word: org.eclipse.tips.feature.feature.group, Length: 38
# Word: [0.4.0.v20230429-1617], Length: 22
# Word: org.eclipse.tips.feature.feature.jar, Length: 36
# Word: [0.3.0.v20230429-1617], Length: 22
# Word: org.eclipse.tm.terminal.connector.local, Length: 39
# Word: [4.8.0.202211062329], Length: 20
# Word: org.eclipse.tm.terminal.connector.local.feature.feature.group, Length: 61
# Word: [11.2.0.202303140100], Length: 21
# Word: org.eclipse.tm.terminal.connector.local.feature.feature.jar, Length: 59
# Word: org.eclipse.tm.terminal.connector.process, Length: 41
# Word: [4.9.0.202211062329], Length: 20
# Word: [4.8.100.202303140100], Length: 22
# Word: org.eclipse.tm.terminal.connector.ssh.feature.feature.group, Length: 59
# Word: org.eclipse.tm.terminal.connector.ssh.feature.feature.jar, Length: 57
# Word: org.eclipse.tm.terminal.connector.telnet, Length: 40
# Word: org.eclipse.tm.terminal.connector.telnet.feature.feature.group, Length: 62
# Word: org.eclipse.tm.terminal.connector.telnet.feature.feature.jar, Length: 60
# Word: [5.4.100.202303140100], Length: 22
# Word: org.eclipse.tm.terminal.control.feature.feature.group, Length: 53
# Word: org.eclipse.tm.terminal.control.feature.feature.jar, Length: 51
# Word: org.eclipse.tm.terminal.feature.feature.group, Length: 45
# Word: [11.2.0.202303131754], Length: 21
# Word: org.eclipse.tm.terminal.feature.feature.jar, Length: 43
# Word: [4.9.100.202303140100], Length: 22
# Word: org.eclipse.tm.terminal.view.feature.feature.group, Length: 50
# Word: [11.2.0.202304132101], Length: 21
# Word: org.eclipse.tm.terminal.view.feature.feature.jar, Length: 48
# Word: [4.11.100.202304132101], Length: 23
# Word: [0.5.4.202305171341], Length: 20
# Word: [0.5.5.202305171341], Length: 20
# Word: [0.6.3.202303141648], Length: 20
# Word: [0.6.4.202305161247], Length: 20
# Word: [3.203.100.v20230417-1307], Length: 26
# Word: [3.8.0.v20230329-1440], Length: 22
# Word: [3.8.0.v20230317-0802], Length: 22
# Word: [3.12.0.v20230317-0802], Length: 23
# Word: [3.16.0.v20230329-1609], Length: 23
# Word: [1.3.0.v20230516-1137], Length: 22
# Word: [3.21.0.v20230526-1500], Length: 23
# Word: [1.5.0.v20230526-1051], Length: 22
# Word: [3.7.0.v20230503-0628], Length: 22
# Word: [1.2.0.v20230429-1610], Length: 22
# Word: [3.5.0.v20230317-0802], Length: 22
# Word: [3.12.0.v20230329-1313], Length: 23
# Word: [3.9.0.v20230317-0802], Length: 22
# Word: org.eclipse.ui.themes, Length: 21
# Word: [1.2.2200.v20230220-0932], Length: 25
# Word: [1.4.0.v20230418-0745], Length: 22
# Word: [3.129.0.v20230525-0648], Length: 24
# Word: [3.17.0.v20230316-1200], Length: 23
# Word: [3.5.0.v20230317-0901], Length: 22
# Word: org.eclipse.userstorage, Length: 23
# Word: [1.2.0.v20210517-0327], Length: 22
# Word: org.eclipse.userstorage.feature.group, Length: 37
# Word: org.eclipse.userstorage.feature.jar, Length: 35
# Word: org.eclipse.userstorage.oauth, Length: 29
# Word: [1.1.0.v20190307-0457], Length: 22
# Word: org.eclipse.userstorage.ui, Length: 26
# Word: [1.1.0.202304242122], Length: 20
# Word: org.eclipse.wildwebdeveloper.xml.feature.feature.group, Length: 54
# Word: org.eclipse.wildwebdeveloper.xml.feature.feature.jar, Length: 52
# Word: org.eclipse.wst.common.core, Length: 27
# Word: [1.4.100.v202103232321], Length: 23
# Word: org.eclipse.wst.common.emf, Length: 26
# Word: [1.2.700.v202007161535], Length: 23
# Word: org.eclipse.wst.common.environment, Length: 34
# Word: [1.0.401.v202007142017], Length: 23
# Word: org.eclipse.wst.common.frameworks, Length: 33
# Word: [1.2.202.v202108200212], Length: 23
# Word: org.eclipse.wst.common.uriresolver, Length: 34
# Word: [1.3.0.v202007161535], Length: 21
# Word: [1.2.1100.v202305221405], Length: 24
# Word: [1.2.700.v202305221615], Length: 23
# Word: [2.5.0.v20161103-1916], Length: 22
# Word: [8.1.1.v20230428-1350], Length: 22
# Word: org.hamcrest.core, Length: 17
# Word: [1.3.0.v20180420-1519], Length: 22
# Word: [0.8.10.202304240956], Length: 21
# Word: [1.0.58], Length: 8
# Word: [2.1.48], Length: 8
# Word: org.jsoup, Length: 9
# Word: [1.15.3], Length: 8
# Word: org.junit, Length: 9
# Word: [4.13.2.v20211018-1956], Length: 23
# Word: org.objectweb.asm, Length: 17
# Word: [9.5.0], Length: 7
# Word: org.objectweb.asm.commons, Length: 25
# Word: org.objectweb.asm.tree, Length: 22
# Word: org.objectweb.asm.tree.analysis, Length: 31
# Word: org.objectweb.asm.util, Length: 22
# Word: org.opentest4j, Length: 14
# Word: [1.2.0], Length: 7
# Word: org.osgi.service.cm, Length: 19
# Word: [1.6.1.202109301733], Length: 20
# Word: org.osgi.service.component, Length: 26
# Word: [1.5.1.202212101352], Length: 20
# Word: org.osgi.service.device, Length: 23
# Word: [1.1.1.202109301733], Length: 20
# Word: org.osgi.service.event, Length: 22
# Word: [1.4.1.202109301733], Length: 20
# Word: org.osgi.service.metatype, Length: 25
# Word: org.osgi.service.prefs, Length: 22
# Word: [1.1.2.202109301733], Length: 20
# Word: org.osgi.service.provisioning, Length: 29
# Word: [1.2.0.201505202024], Length: 20
# Word: org.osgi.service.upnp, Length: 21
# Word: [1.2.1.202109301733], Length: 20
# Word: org.osgi.service.useradmin, Length: 26
# Word: org.osgi.service.wireadmin, Length: 26
# Word: [1.0.2.202109301733], Length: 20
# Word: org.osgi.util.function, Length: 22
# Word: [1.2.0.202109301733], Length: 20
# Word: org.osgi.util.measurement, Length: 25
# Word: [1.0.2.201802012109], Length: 20
# Word: org.osgi.util.position, Length: 22
# Word: [1.0.1.201505202026], Length: 20
# Word: org.osgi.util.promise, Length: 21
# Word: [1.3.0.202212101352], Length: 20
# Word: org.osgi.util.xml, Length: 17
# Word: org.sat4j.core, Length: 14
# Word: [2.3.6.v20201214], Length: 17
# Word: org.sat4j.pb, Length: 12
# Word: org.slf4j.api, Length: 13
# Word: [1.7.30.v20221112-0806], Length: 23
# Word: org.tukaani.xz, Length: 14
# Word: [1.9.0], Length: 7
# Word: org.w3c.css.sac, Length: 15
# Word: [1.3.1.v200903091627], Length: 21
# Word: org.w3c.dom.events, Length: 18
# Word: [3.0.0.draft20060413_v201105210656], Length: 35
# Word: org.w3c.dom.smil, Length: 16
# Word: [1.0.1.v200903091627], Length: 21
# Word: org.w3c.dom.svg, Length: 15
# Word: [1.1.0.v201011041433], Length: 21
# Word: org.yaml.snakeyaml, Length: 18
# Word: [1.27.0.v20221112-0806], Length: 23
# Word: slf4j.api, Length: 9
# Word: [2.0.7], Length: 7
# Word: slf4j.nop, Length: 9
# Word: tooling.org.eclipse.update.feature.default, Length: 42
# Word: [1.0.0], Length: 7
# Word: tooling.osgi.bundle.default, Length: 27
# Word: tooling.source.default, Length: 22
# Word: toolingepp.package.java.application, Length: 35
# Word: toolingepp.package.java.config.win32.win32.x86_64, Length: 49
# Word: toolingepp.package.java.configuration, Length: 37
# Word: toolingepp.package.java.executable.win32.win32.x86_64, Length: 53
# Word: toolingepp.package.java.ini.win32.win32.x86_64, Length: 46
# Word: toolingorg.eclipse.epp.java.configuration, Length: 41
# Word: toolingorg.eclipse.equinox.launcher, Length: 35
# Word: toolingorg.eclipse.equinox.launcher.win32.win32.x86_64, Length: 54
# Word: toolingwin32.win32.x86_64org.apache.felix.scr, Length: 45
# Word: toolingwin32.win32.x86_64org.eclipse.core.runtime, Length: 49
# Word: toolingwin32.win32.x86_64org.eclipse.equinox.common, Length: 51
# Word: toolingwin32.win32.x86_64org.eclipse.equinox.event, Length: 50
# Word: toolingwin32.win32.x86_64org.eclipse.equinox.p2.reconciler.dropins, Length: 66
# Word: toolingwin32.win32.x86_64org.eclipse.equinox.simpleconfigurator, Length: 63
# Word: 21:53:42], Length: 9
# Word: Preparing, Length: 9
# Word: commit, Length: 6
# Word: the, Length: 3
# Word: provisioning, Length: 12
# Word: operation., Length: 10
# Word: Committing, Length: 10
# Word: 21:53:43], Length: 9
# Word: Eclipse, Length: 7
# Word: Ini, Length: 3
# Word: --launcher.appendVmargs, Length: 23
# Word: -Declipse.p2.max.threads=10, Length: 27
# Word: Changing, Length: 8
# Word: C:\Users\eluri\eclipse\java-2023-06\eclipse\eclipse.ini, Length: 55
# Word: (-Declipse.p2.max.threads=10), Length: 29
# Word: -Doomph.update.url=https://download.eclipse.org/oomph/updates/milestone/latest, Length: 78
# Word: (-Doomph.update.url=https://download.eclipse.org/oomph/updates/milestone/latest), Length: 80
# Word: -Doomph.redirection.index.redirection=index:/->http://git.eclipse.org/c/oomph/org.eclipse.oomph.git/plain/setups/, Length: 113
# Word: (-Doomph.redirection.index.redirection=index:/->http://git.eclipse.org/c/oomph/org.eclipse.oomph.git/plain/setups/), Length: 115
# Word: post, Length: 4

# %%
#iii. Write the word-length dictionary to output.txt in the following format:
    
#iv.Close both input and comput files property

# %%
log_file_path = "D:\practise\logfile.txt" 
word_lengths = {}  

try:
    with open("D:\practise\logfile.txt", 'r') as log_file:
        log_content = log_file.read()
        words = log_content.split()
        for word in words:
            word_lengths[word] = len(word)
        with open("output.txt", "w") as output_file:
            for word, length in word_lengths.items():
                output_file.write(f"{word}: {length}\n")

        print("Word-length dictionary has been written to output.txt")
except FileNotFoundError:
    print(f"The file '{log_file_path}' was not found.")
except Exception as e:
    print(f"An error occurred: {str(e)}")
output_file.close()
# Out:
# Word-length dictionary has been written to output.txt

# %% [markdown]
# # 8.Assume that you are developing a student gradebook system for a school. The system should allow teachers to input student grades for various subjects, store the data in files, and provide students with the ability to view their grades.
#
# Design a Python program that accomplishes the following tasks:
#
# i.Teachers should be able to input grades for students in different subjects.
#
# ii. Store the student grade data in separate text files for each subject.
#
# iii. Students should be able to view their grades for each subject.
#
# iv. Implement error handling for file operations, such as file not found or permission issues.

# %%
import os

# to input and store student grades for a subject
def input_grades(subject):
    try:
        file_name = f"{subject}.txt"
        with open(file_name, "a") as file:
            student_name = input("Enter student name: ")
            grade = input(f"Enter {subject} grade for {student_name}: ")
            file.write(f"{student_name}: {grade}\n")
        print(f"Grade for {student_name} in {subject} has been recorded.")
    except IOError as e:
        print(f"Error: {e}")

# to view student grades for a subject
def view_grades(subject):
    try:
        file_name = f"{subject}.txt"
        if not os.path.exists(file_name):
            print(f"No grades recorded for {subject} yet.")
            return

        with open(file_name, "r") as file:
            print(f"Grades for {subject}:")
            for line in file:
                print(line.strip())
    except IOError as e:
        print(f"Error: {e}")

while True:
    print("\nStudent Gradebook System")
    print("1. Input Grades")
    print("2. View Grades")
    print("3. Exit")

    choice = input("Enter your choice (1/2/3): ")

    if choice == "1":
        subject = input("Enter the subject: ")
        input_grades(subject)
    elif choice == "2":
        subject = input("Enter the subject: ")
        view_grades(subject)
    elif choice == "3":
        break
    else:
        print("Invalid choice. Please enter 1, 2, or 3.")

print("Goodbye!")
# Out:
# Student Gradebook System
# 1. Input Grades
# 2. View Grades
# 3. Exit
# Enter your choice (1/2/3): 1
# Enter the subject: 2
# Enter student name: vishal
# Enter 2 grade for vishal: A B
# Grade for vishal in 2 has been recorded.
#
# Student Gradebook System
# 1. Input Grades
# 2. View Grades
# 3. Exit
# Enter your choice (1/2/3): 3
# Goodbye!
