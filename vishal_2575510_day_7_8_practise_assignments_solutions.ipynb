# %% [markdown]
# # 1. Write a Python program to find a target values in a list using linear search with following steps
#
# a. Initialize the list to store the input elements.
#
# b. Initialize found=False.
#
# C Enter the item to be searched (match_item).
#
# d. For each element in the list
#
#     1. if match_item = value
#
#           a. return match_item's position.
#
# e. If the match_item is not in the list, display an error message that the item is not found in the list.

# %%
data=[]
n=int(input('Enter no of elements to be inserted:\t'))
for i in range(0,n):
    x=int(input('Enter the Element %d:'%(i+1)))
    data.append(x)

e=int(input('Enter the value to be searched: \t'))
pos=0
found=False
while pos <n and not found:
    if data[pos]==e:
        found=True
    else:
        pos+=1

if found:
    print('Element %d Found at Position %d'%(e,pos+1))

else:
    print('Element %d not found in the list'%e)

print(data)
# Out:
# Enter no of elements to be inserted:	4
# Enter the Element 1:12
# Enter the Element 2:14
# Enter the Element 3:67
# Enter the Element 4:89
# Enter the value to be searched: 	89
# Element 89 Found at Position 4
# [12, 14, 67, 89]

# %% [markdown]
# # 2. Write a Python program to implement binary search to find the target values from the list:
#
# a. Create a separate function to do binary search.
#
# b. Get the number of inputs from the user
#
# C. Store the inputs individually in a list.
#
# d. In binary search function at first sort the list in order to start the search from middle of the list.
#
# e Compare the middle element to right and left elements to search target element
#
# f. If greater, move to right of list or else move to another side of the list.
#
# g. Print the result along with the position of the element.

# %%
def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    
    while left <= right:
        mid = (left + right) // 2
        mid_value = arr[mid]
        
        if mid_value == target:
            return f"Element {target} found at position {mid}"
        elif mid_value < target:
            left = mid + 1
        else:
            right = mid - 1
    
    return f"Element {target} not found in the list"

input_list = [int(x) for x in input("Enter a list of numbers separated by spaces: ").split()]
target_value = int(input("Enter the target value to search for: "))
result = binary_search(input_list, target_value)
print(result)
# Out:
# Enter a list of numbers separated by spaces: 12 3 4 5 6
# Enter the target value to search for: 5
# Element 5 found at position 3

# %% [markdown]
# # 3. Write a Python program for sorting a list of elements using selection sort algorithm:
#
# a.Assume two lists: Sorted list- Initially empty and Unsorted List-Given input list.
#
# b. In the first iteration, find the smallest element in the unsorted list and place it in the sorte list.
#
# c. In the second iteration, find the smallest element in the unsorted list and place it in the correct position by comparing with the element in the sorted list.
#
# d. In the third iteration, again find the smallest element in the unsorted list and place it in the correct position by comparing with the elements in the sorted list.
#
# e. This process continues till the unsorted list becomes empty.
#
# f. Display the sorted list.

# %%
def selection_sort(arr):
    sorted_list = [] 
    while arr: 
        min_val = min(arr) 
        sorted_list.append(min_val)  
        arr.remove(min_val) 

    return sorted_list


unsorted_list = [64, 25, 12, 22, 11]
sorted_list = selection_sort(unsorted_list)
print("Sorted List:", sorted_list)
# Out:
# Sorted List: [11, 12, 22, 25, 64]

# %% [markdown]
# # 4. Write a Python program for sorting a list of elements using insertion sort algorithm:
#
# a. Assume two lists: Sorted list- Initially empty and Unsorted List-Given input list. b. In the first iteration, take the first element in the unsorted list and insert it in Sorted list.
#
# C. In the second iteration, take the second element in the given list and compare with the element in the sorted sub list and place it in the correct position.
#
# d. In the third iteration, take the third element in the given list and compare with the elements in the sorted sub list and place the elements in the correct position.
#
# e. This process continues until the last element is inserted in the sorted sub list.
#
# f. Display the sorted elements.

# %%
def insertion_sort(input_list):
    sorted_list = []

    for unsorted_element in input_list:
        if not sorted_list:
            sorted_list.append(unsorted_element)
        else:
            for i in range(len(sorted_list)):
                if unsorted_element < sorted_list[i]:
                    sorted_list.insert(i, unsorted_element)
                    break
            else:
                sorted_list.append(unsorted_element)

    return sorted_list

if __name__ == "__main__":
    input_list = [12, 11, 13, 5, 6]
    sorted_list = insertion_sort(input_list)
    print("Sorted list:", sorted_list)
# Out:
# Sorted list: [5, 6, 11, 12, 13]

# %% [markdown]
# # 5. Write a Python program that performs merge sort on a list of numbers:
#
# a. Divide: If the given array has zero or one element, return.
#
# 1. Otherwise
#
# ii. Divide the input list in to two halves each containing half of the elements. i.e. left half and right half.
#
# b. Conquer: Recursively sort the two lists (left half and right half).
#
# a. Call the merge sort on left half.
#
# b. Call the merge sort on right half.
#
# C. Combine: Combine the elements back in the input list by merging the two sorted lists into a sorted sequence.

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    left_half = merge_sort(left_half)
    right_half = merge_sort(right_half)

    merged = []
    left_idx, right_idx = 0, 0

    while left_idx < len(left_half) and right_idx < len(right_half):
        if left_half[left_idx] < right_half[right_idx]:
            merged.append(left_half[left_idx])
            left_idx += 1
        else:
            merged.append(right_half[right_idx])
            right_idx += 1

    merged.extend(left_half[left_idx:])
    merged.extend(right_half[right_idx:])

    return merged

def get_user_input():
    try:
        input_list = input("Enter a list of numbers separated by spaces: ")
        input_list = [int(x) for x in input_list.split()]
        return input_list
    except ValueError:
        print("Invalid input. Please enter a list of numbers.")
        return get_user_input()

if __name__ == "__main__":
    print("Welcome to Merge Sort!")

    input_list = get_user_input()
    sorted_list = merge_sort(input_list)

    print("Original array:", input_list)
    print("Sorted array:", sorted_list)
# Out:
# Welcome to Merge Sort!
# Enter a list of numbers separated by spaces: 12 45  56 67 78 78
# Original array: [12, 45, 56, 67, 78, 78]
# Sorted array: [12, 45, 56, 67, 78, 78]

# %% [markdown]
# # 6. Write a Python script to perform the following operations on a singly linked list
#
# a. Create a list
#
# b. Find the smallest element from the list
#
# C.Insert an element if it is not a duplicate element
#
# d. Display the elements in reverse order

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def create_list(self, elements):
        for element in elements:
            new_node = Node(element)
            if not self.head:
                self.head = new_node
            else:
                current = self.head
                while current.next:
                    current = current.next
                current.next = new_node

    def find_smallest(self):
        if not self.head:
            return None

        smallest = self.head.data
        current = self.head.next

        while current:
            if current.data < smallest:
                smallest = current.data
            current = current.next

        return smallest

    def insert_if_not_duplicate(self, element):
        if not self.head:
            self.head = Node(element)
            return

        current = self.head
        while current.next:
            if current.data == element:
                return  
            current = current.next

        if current.data != element:
            current.next = Node(element)

    def display_reverse(self):
        if not self.head:
            return []

        elements = []
        current = self.head
        while current:
            elements.append(current.data)
            current = current.next

        return elements[::-1]

if __name__ == "__main__":
    elements = [int(x) for x in input("Enter elements separated by spaces: ").split()]
    linked_list = LinkedList()
    linked_list.create_list(elements)

    smallest = linked_list.find_smallest()
    if smallest is not None:
        print(f"The smallest element in the list is: {smallest}")
    else:
        print("The list is empty.")

    element_to_insert = int(input("Enter an element to insert: "))
    linked_list.insert_if_not_duplicate(element_to_insert)

    reversed_elements = linked_list.display_reverse()
    if reversed_elements:
        print("Elements in reverse order:", reversed_elements)
    else:
        print("The list is empty.")
# Out:
# Enter elements separated by spaces: 12 34 56 78 89
# The smallest element in the list is: 12
# Enter an element to insert: 45
# Elements in reverse order: [45, 89, 78, 56, 34, 12]

# %% [markdown]
# # 7.Write a python program to implement the various operations for Stack ADT 1.) Push ii.) Pop iii.) Display.

# %%
class Stack:
    def __init__(self):
        self.items = []

    def push(self, item):
        self.items.append(item)

    def pop(self):
        if not self.is_empty():
            return self.items.pop()
        else:
            return "Stack is empty"

    def display(self):
        return self.items

if __name__ == "__main__":
    stack = Stack()

    while True:
        print("\nStack Operations:")
        print("1. Push")
        print("2. Pop")
        print("3. Display")
        print("4. Quit")

        choice = input("Enter your choice (1/2/3/4): ")

        if choice == '1':
            item = input("Enter the item to push onto the stack: ")
            stack.push(item)
            print(f"{item} pushed onto the stack.")
        elif choice == '2':
            popped_item = stack.pop()
            print(f"Popped item: {popped_item}")
        elif choice == '3':
            stack_items = stack.display()
            print("Stack:", stack_items)
        elif choice == '4':
            print("Exiting the program.")
            break
        else:
            print("Invalid choice. Please select a valid option.")
# Out:
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter the item to push onto the stack: 23
# 23 pushed onto the stack.
#
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter the item to push onto the stack: 45
# 45 pushed onto the stack.
#
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 3
# Stack: ['23', '45']
#
# Stack Operations:
# 1. Push
# 2. Pop
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 34
#      32     print(f"{item} pushed onto the stack.")
#      33 elif choice == '2':
# ---> 34     popped_item = stack.pop()
#      35     print(f"Popped item: {popped_item}")
#      36 elif choice == '3':
#
# Cell In[8], line 9, in Stack.pop(self)
#       8 def pop(self):
# ----> 9     if not self.is_empty():
#      10         return self.items.pop()
#      11     else:
#
# AttributeError: 'Stack' object has no attribute 'is_empty'

# %% [markdown]
# # 8. Write a python script to implement the various operations for Queue ADT 1.) Insert ii.) Delete iii.) Display

# %%
class Queue:
    def __init__(self):
        self.items = []

    def insert(self, item):
        self.items.append(item)

    def delete(self):
        if not self.is_empty():
            return self.items.pop(0)
        else:
            return "Queue is empty"

    def display(self):
        return self.items

if __name__ == "__main__":
    queue = Queue()

    while True:
        print("\nQueue Operations:")
        print("1. Insert")
        print("2. Delete")
        print("3. Display")
        print("4. Quit")

        choice = input("Enter your choice (1/2/3/4): ")

        if choice == '1':
            item = input("Enter the item to insert into the queue: ")
            queue.insert(item)
            print(f"{item} inserted into the queue.")
        elif choice == '2':
            deleted_item = queue.delete()
            print(f"Deleted item: {deleted_item}")
        elif choice == '3':
            queue_items = queue.display()
            print("Queue:", queue_items)
        elif choice == '4':
            print("Exiting the program.")
            break
        else:
            print("Invalid choice. Please select a valid option.")
# Out:
# Queue Operations:
# 1. Insert
# 2. Delete
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter the item to insert into the queue: 23
# 23 inserted into the queue.
#
# Queue Operations:
# 1. Insert
# 2. Delete
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 1
# Enter the item to insert into the queue: 56
# 56 inserted into the queue.
#
# Queue Operations:
# 1. Insert
# 2. Delete
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 3
# Queue: ['23', '56']
#
# Queue Operations:
# 1. Insert
# 2. Delete
# 3. Display
# 4. Quit
# Enter your choice (1/2/3/4): 2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 34
#      32     print(f"{item} inserted into the queue.")
#      33 elif choice == '2':
# ---> 34     deleted_item = queue.delete()
#      35     print(f"Deleted item: {deleted_item}")
#      36 elif choice == '3':
#
# Cell In[9], line 9, in Queue.delete(self)
#       8 def delete(self):
# ----> 9     if not self.is_empty():
#      10         return self.items.pop(0)
#      11     else:
#
# AttributeError: 'Queue' object has no attribute 'is_empty'

# %% [markdown]
# # 9. Write a program in python to convert the following infix expression to its postfix form using push and pop operations of a Stack
#
# a. A/B^C+D*E-F*G
#
# b. (B^2-4*A*C)^(1/2) (100)

# %%
class Stack:
    def __init__(self):
        self.items = []

    def push(self, item):
        self.items.append(item)

    def pop(self):
        if not self.is_empty():
            return self.items.pop()
        else:
            return None

    def peek(self):
        if not self.is_empty():
            return self.items[-1]
        else:
            return None

    def is_empty(self):
        return len(self.items) == 0

def infix_to_postfix(expression):
    precedence = {'+':1, '-':1, '*':2, '/':2, '^':3}
    output = []
    stack = Stack()

    for char in expression:
        if char.isalnum():  # Operand, add to output
            output.append(char)
        elif char == '(':  # Left parenthesis, push to stack
            stack.push(char)
        elif char == ')':  # Right parenthesis, pop from stack and append to output until '(' is encountered
            while not stack.is_empty() and stack.peek() != '(':
                output.append(stack.pop())
            if not stack.is_empty() and stack.peek() == '(':
                stack.pop()
        else:  # Operator
            while (not stack.is_empty() and
                   stack.peek() != '(' and
                   precedence[char] <= precedence.get(stack.peek(), 0)):
                output.append(stack.pop())
            stack.push(char)

    # Pop any remaining operators from the stack and append to output
    while not stack.is_empty():
        output.append(stack.pop())

    return ''.join(output)

# Test cases
infix_expr1 = "A/B^C+D*E-F*G"
infix_expr2 = "(B^2-4*A*C)^(1/2)*(100)"

postfix_expr1 = infix_to_postfix(infix_expr1)
postfix_expr2 = infix_to_postfix(infix_expr2)

print("Infix Expression 1:", infix_expr1)
print("Postfix Expression 1:", postfix_expr1)

print("\nInfix Expression 2:", infix_expr2)
print("Postfix Expression 2:", postfix_expr2)
# Out:
# Infix Expression 1: A/B^C+D*E-F*G
# Postfix Expression 1: ABC^/DE*+FG*-
#
# Infix Expression 2: (B^2-4*A*C)^(1/2)*(100)
# Postfix Expression 2: B2^4A*C*-12/^100*
